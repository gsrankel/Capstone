# %% [markdown]
# # Starbucks and MTA Data

# %% [markdown]
# ## Problem Statement:
# Starbucks is a premier international coffee franchise with over 30,000 locations throughout the world. With New York City being one of the top cities to consume coffee, in all of the United States, Starbucks has imprinted its mark throughout the city, opening up more than 400 stores throughout the 5 boroughs, with 240 being specifically in Manhattan.
#
# The Metropolitan Transportation Authority (MTA) has become a very viable and popular means of transportation for people in New York City, seamlessly aiding people in getting to various part of the city that may be too far to walk or too expensive to take a taxi/uber to get too. With this means of transportation, thousands of people go through these arrays of turnstiles which leads to greater foot traffic in these general areas at certain times which would make it prime real estate to open up a Starbucks store.  On the other side of the coin, it will also tell us which stores maybe are losing foot traffic and will need to be looked into more to see if there has been a decrease in these stores profit and loss statements which may need to lead to relocation or shut down permanently. With looking at this turnstile data that the MTA provided, can we identify trends happening around certain subway stations that can possibly lead to expansion opportunities as well as mitigate risk with certain stores that aren’t becoming as popular
#
# We will assess our data with a time series analysis, using historical data of these stations and turnstiles to predict future foot traffic in each of the various locations. We will use the Seasonal Auto Regression Integrated Moving Average Exonginous (SARIMAX) model to evaluate and use regression, specifically Root Mean Squared Error (RMSE), to score our models.

# %% [markdown]
# ![](800px-MTA_New_York_City_Subway_logo.svg.png)
# ![](Starbucks_Corporation_Logo_2011.svg.png)

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# - [1.4 Acquiring and Preprocessing Data](#Acquiring-and-Preprocessing-Data)
# - [1.5 Data Dictionary](#Data-Dictionary)
# - [1.6 Loading Libraries](#Loading-Libraries)
# - [1.7 Loading Data](#Loading-Data)
# - [1.8 EDA](#EDA)
# - [1.9 Featured Engineering](#CFeatured-Engineering)
# - [1.10 Model Preparation](#Model-Preparation)
# - [1.11 Modeling](#Modeling)
# - [1.12 Model Selection](#Model-Selection)
# - [1.13 Model Evaluation](#Model-Evaluation)
# - [1.14 Conclusion](#Conclusion)
# - [1.15 Conclusion](#Conclusion)

# %% [markdown]
# ## Acquiring and Preprocessing Data

# %% [markdown]
# __Talk about other notebook__

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# |Feature|Type|Description|
# |---|---|---|
# |**State**|*object*|State|
# |**City**|*object*|City|
# |**Zip Codes**|*int*|Zip Code |
# |**Latitude**|*float*|Latitude |
# |**Longitude**|*float*|Longitude|
# |**ID**|*object*|Unique ID of each Data point|
# |**Name**|*object*|Store/Restaurant Name|
# |**Review Count**|*int*|Number of reviews
# |**Categories**|*object*|Category of each point|
# |**Rating**|*float*|Average rating of each point|
# |**Price**|*int*|Amount of $ signs of each point|
# |**High Value**|*float*|Average Adjusted Gross Income of people who made over 200,000 per Zip Code|
# |**AGI Sum**|*float*|Sum of the Total Average Income per threshold per Zip Code|
# |**Aff Perc**|*float*|Rate of Affluency per Zip Code (High Value /AGI Sum)|
# |**Count**|*int*|Count of Restaurants in particular Zip Code|

# %% [markdown]
# ## Loading Libraries

# %%
#cleaning libraries
import requests
import pandas as pd
import numpy as np
from PIL import Image
from difflib import get_close_matches 
#evaluation
import statsmodels.api as sm
from sklearn.pipeline import Pipeline,FeatureUnion
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans

from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.stattools import adfuller  
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

#graphs
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Load the stations CSV we created in the Starbucks Cleaning notebook

# %%
stations = pd.read_csv('Data/stations.csv')
stations.head()
# Out:
#    Station_Latitude  Station_Longitude  Route_8  Route_9  Route_10  Route_11  \
# 0         40.740893         -74.001690      NaN      NaN       NaN       NaN
# 1         40.745906         -73.998041      NaN      NaN       NaN       NaN
# 2         40.747846         -73.946000      NaN      NaN       NaN       NaN
# 3         40.752287         -73.993391      NaN      NaN       NaN       NaN
# 4         40.757308         -73.989735      1.0      2.0       3.0       7.0
#
#    ADA  Free_Crossover   Latitude  Longitude         station  first_closest  \
# 0  1.0             1.0  40.740612 -74.001896         14th St       0.001861
# 1  0.0             1.0  40.745990 -73.997927         23rd St       0.003181
# 2  0.0             1.0  40.747807 -73.945829  23rd St-Ely Av       0.013156
# 3  1.0             1.0  40.752218 -64.744260         34th St       0.001281
# 4  1.0             1.0  40.757358 -73.989816         42nd St       0.000612
#
#              first_closest_store  second_closest second_closest_store  \
# 0  8th Ave just south of 14th St        0.002499           19th & 8th
# 1                     24th & 7th        0.003717           19th & 8th
# 2               Roosevelt Island        0.021601         69th & First
# 3          Penn Station by A,C,E        0.001281       One Penn Plaza
# 4                     42nd & 8th        0.000680    Union Square East
#
#    third_closest       third_closest_store
# 0       0.003523  Greenwich Ave at Bank St
# 1       0.003729                23rd & 1st
# 2       0.023777              75th & First
# 3       0.003779       32nd btwn 6th & 7th
# 4       0.001043                43rd & 8th

# %% [markdown]
# Load in the 2017 Turnstile data that we were able to obtain from the MTA website

# %%
df_2017 = pd.read_csv('Data/turnstile-usage-data-2017.csv')

# %%
df_2017.head()
# Out:
#     C/A  Unit       SCP Station Line Name Division                     Date  \
# 0  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 1  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 2  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 3  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 4  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
#
#        Time Description  Entries  \
# 0  23:00:00     REGULAR  6455787
# 1  19:00:00     REGULAR  6455505
# 2  15:00:00     REGULAR  6454819
# 3  11:00:00     REGULAR  6454437
# 4  07:00:00     REGULAR  6454285
#
#    Exits
# 0                                            2184977
# 1                                            2184926
# 2                                            2184867
# 3                                            2184773
# 4                                            2184501

# %% [markdown]
# ## Preliminary EDA

# %% [markdown]
# Within the Preliminary EDA, we will setup one Dataframe that will be used to start feature engineering and setting up various graphs to look at

# %%
df_2017.describe()
# Out:
#             Entries  \
# count  5.570560e+06
# mean   4.805249e+07
# std    2.379585e+08
# min    0.000000e+00
# 25%    8.337350e+05
# 50%    3.087662e+06
# 75%    6.773083e+06
# max    2.032571e+09
#
#        Exits
# count                                       5.570560e+06
# mean                                        3.908922e+07
# std                                         2.096464e+08
# min                                         0.000000e+00
# 25%                                         4.219682e+05
# 50%                                         1.875607e+06
# 75%                                         5.330796e+06
# max                                         2.140537e+09

# %% [markdown]
# When looking at the decribe statistics, the maximum do look high as these are cumulative totals. We will adjust to make them daily totals later on.

# %%
df_2017.isnull().sum()
# Out:
# C/A                                                           0
# Unit                                                          0
# SCP                                                           0
# Station                                                       0
# Line Name                                                     0
# Division                                                      0
# Date                                                          0
# Time                                                          0
# Description                                                   0
# Entries                                                       0
# Exits                                                         0
# dtype: int64

# %% [markdown]
# Noted that there are not null values within the data set

# %%
len(df_2017['Line Name'])
# Out:
# 8880000

# %%
df_2017['Line Name'].unique()
# Out:
# array(['NQR456W', 'NQRW', 'ACENQRS1237W', 'BDFMNQRW', 'NRW', 'LNQR456W',
#        'JNQRZ6W', 'RNW', 'R1W', 'FJMZ', 'JZ', 'JZ456', 'ACJZ2345', 'BQ',
#        'S', 'S2345', 'BQS', 'Q', 'R2345', 'R', 'BDNQR', 'BDNQR2345',
#        'DFGMNR', 'DNR', 'N', 'ND', 'D', 'DFNQ', 'ACEL', 'FLM123', 'L',
#        'LG', 'LM', 'JMZ', 'JM', 'J', 'A', 'E', 'M', 'AC1', 'C', 'ABCD',
#        'BC', 'ACBD', 'ABCD1', 'ACENGRS1237W', 'ACE', 'CE', 'ABCDEFM',
#        'ACE23', '2345ACJZ', 'AC', 'ACF', 'ACG', 'ACS', 'ACJLZ', 'AS',
#        'BD', 'BD4', 'BDE', 'EM', 'EM6', 'EMG', 'EMR', 'MR', 'EFMR7',
#        'EFMR', 'EF', 'F', 'G', 'GL', 'BDFM', 'BDFM7', 'FM', 'BDFQ6', 'FG',
#        '1', 1, '1RW', '23', '123', '123FLM', 123, '1237ACENQRSW', '1ABCD',
#        45], dtype=object)

# %%
df_2017 = df_2017[(df_2017['Line Name']!= 1) & (df_2017['Line Name']!= 123) & (df_2017['Line Name']!= 45)]

# %%
df_2017.loc[df_2017["Station"] == "50 ST","Line Name"]= df_2017.loc[df_2017["Station"] == "50 ST","Line Name"].replace('D', 'E')

# %%
df_e = df_2017.loc[df_2017['Line Name'].str.contains('E'),:]

# %%
df_e['Station'].sort_values().unique()
# Out:
# array(['14 ST', '23 ST', '34 ST-PENN STA', '42 ST-PORT AUTH',
#        '5 AV/53 ST', '50 ST', '7 AV', '75 AV', '8 AV', 'BRIARWOOD',
#        'CANAL ST', 'CHAMBERS ST', 'COURT SQ', 'COURT SQ-23 ST',
#        'FOREST HILLS 71', 'JFK JAMAICA CT1', 'JKSN HT-ROOSVLT',
#        'KEW GARDENS', 'LEXINGTON AV/53', 'QUEENS PLAZA', 'SPRING ST',
#        'TIMES SQ-42 ST', 'W 4 ST-WASH SQ', 'WORLD TRADE CTR'],
#       dtype=object)

# %%
len(df_e)
# Out:
# 890571

# %%
del(df_2017)

# %%
def date_manip(df):
    new_date = [i.split('T')[0] for i in df['Date']]
    df['Date'] = new_date
    df['date_time'] = pd.to_datetime(df.Date + ' ' + df.Time)
    return df.head()

# %%
date_manip(df_e)
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               Date      Time Description  Entries  \
# 118432  2017-12-22  23:00:00     REGULAR  7357995
# 118433  2017-12-22  19:00:00     REGULAR  7357446
# 118434  2017-12-22  15:00:00     REGULAR  7356450
# 118435  2017-12-22  11:00:00     REGULAR  7355728
# 118436  2017-12-22  07:00:00     REGULAR  7355235
#
#         Exits                                                       \
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730
#
#                  date_time
# 118432 2017-12-22 23:00:00
# 118433 2017-12-22 19:00:00
# 118434 2017-12-22 15:00:00
# 118435 2017-12-22 11:00:00
# 118436 2017-12-22 07:00:00

# %%
def doy(day):
    return day.day_name()

# %%
def moy(month):
    return month.month_name()

# %%
def map_day_to_df(df):
    df['day'] = df['date_time'].map(doy)
    return df.head()

# %%
def map_month_to_df(df):
    df['month'] = df['date_time'].map(moy)
    return df.head()

# %%
map_day_to_df(df_e)
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               Date      Time Description  Entries  \
# 118432  2017-12-22  23:00:00     REGULAR  7357995
# 118433  2017-12-22  19:00:00     REGULAR  7357446
# 118434  2017-12-22  15:00:00     REGULAR  7356450
# 118435  2017-12-22  11:00:00     REGULAR  7355728
# 118436  2017-12-22  07:00:00     REGULAR  7355235
#
#         Exits                                                       \
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730
#
#                  date_time     day
# 118432 2017-12-22 23:00:00  Friday
# 118433 2017-12-22 19:00:00  Friday
# 118434 2017-12-22 15:00:00  Friday
# 118435 2017-12-22 11:00:00  Friday
# 118436 2017-12-22 07:00:00  Friday

# %%
map_month_to_df(df_e)
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               Date      Time Description  Entries  \
# 118432  2017-12-22  23:00:00     REGULAR  7357995
# 118433  2017-12-22  19:00:00     REGULAR  7357446
# 118434  2017-12-22  15:00:00     REGULAR  7356450
# 118435  2017-12-22  11:00:00     REGULAR  7355728
# 118436  2017-12-22  07:00:00     REGULAR  7355235
#
#         Exits                                                       \
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730
#
#                  date_time     day     month
# 118432 2017-12-22 23:00:00  Friday  December
# 118433 2017-12-22 19:00:00  Friday  December
# 118434 2017-12-22 15:00:00  Friday  December
# 118435 2017-12-22 11:00:00  Friday  December
# 118436 2017-12-22 07:00:00  Friday  December

# %%
stations['station'] = stations['station'].str.upper()

# %%
stations.head()
# Out:
#    Station_Latitude  Station_Longitude  Route_8  Route_9  Route_10  Route_11  \
# 0         40.740893         -74.001690      NaN      NaN       NaN       NaN
# 1         40.745906         -73.998041      NaN      NaN       NaN       NaN
# 2         40.747846         -73.946000      NaN      NaN       NaN       NaN
# 3         40.752287         -73.993391      NaN      NaN       NaN       NaN
# 4         40.757308         -73.989735      1.0      2.0       3.0       7.0
#
#    ADA  Free_Crossover   Latitude  Longitude         station  first_closest  \
# 0  1.0             1.0  40.740612 -74.001896         14TH ST       0.001861
# 1  0.0             1.0  40.745990 -73.997927         23RD ST       0.003181
# 2  0.0             1.0  40.747807 -73.945829  23RD ST-ELY AV       0.013156
# 3  1.0             1.0  40.752218 -64.744260         34TH ST       0.001281
# 4  1.0             1.0  40.757358 -73.989816         42ND ST       0.000612
#
#              first_closest_store  second_closest second_closest_store  \
# 0  8th Ave just south of 14th St        0.002499           19th & 8th
# 1                     24th & 7th        0.003717           19th & 8th
# 2               Roosevelt Island        0.021601         69th & First
# 3          Penn Station by A,C,E        0.001281       One Penn Plaza
# 4                     42nd & 8th        0.000680    Union Square East
#
#    third_closest       third_closest_store
# 0       0.003523  Greenwich Ave at Bank St
# 1       0.003729                23rd & 1st
# 2       0.023777              75th & First
# 3       0.003779       32nd btwn 6th & 7th
# 4       0.001043                43rd & 8th

# %% [markdown]
# The next step we had to take was to find a way to merge now our two station data sets together, one with the station locations and closest starbucks and the other with the turnstile info. For that, we needed to get teh station names to match up together. We had to make a conversion dictionary that would then be mapped to our station location dataframe as a means of merging them together. With the help of the get_close_matches fucntion. this expediated the process for us to search within the unique values of the turnstile dataframe to match the closest named station which did work at about a 75% clip. The other 25% where it wasnt able to indentify, we had to mannually go through the list to figure out the matching station.

# %%
from difflib import SequenceMatcher,get_close_matches

SequenceMatcher(None,'Prospect Park' , 'PROSPECT PARK').ratio()
# Out:
# 0.23076923076923078

# %%
stations['station'].sort_values().unique()
# Out:
# array(['14TH ST', '23RD ST', '23RD ST-ELY AV', '34TH ST', '42ND ST',
#        '45 RD-COURT HOUSE SQ', '50TH ST', '51ST ST', '5TH AV-53RD ST',
#        '75TH AV', '7TH AV', '8TH AV', 'BROADWAY-74TH ST', 'CANAL ST',
#        'CHAMBERS ST', 'FOREST HILLS-71ST AV',
#        'JACKSON HEIGHTS-ROOSEVELT AVE', 'JAMAICA-VAN WYCK',
#        'KEW GARDENS-UNION TURNPIKE', 'LEXINGTON AV-53RD ST', 'PARK PLACE',
#        'PARSONS BLVD-ARCHER AV - JAMAICA CENTER', 'QUEENS PLAZA',
#        'SPRING ST', 'SUTPHIN BLVD-ARCHER AV - JFK', 'TIMES SQUARE',
#        'TIMES SQUARE-42ND ST', 'WEST 4TH ST', 'WORLD TRADE CENTER'],
#       dtype=object)

# %%
df_e['Station'].sort_values().unique()
# Out:
# array(['14 ST', '23 ST', '34 ST-PENN STA', '42 ST-PORT AUTH',
#        '5 AV/53 ST', '50 ST', '7 AV', '75 AV', '8 AV', 'BRIARWOOD',
#        'CANAL ST', 'CHAMBERS ST', 'COURT SQ', 'COURT SQ-23 ST',
#        'FOREST HILLS 71', 'JFK JAMAICA CT1', 'JKSN HT-ROOSVLT',
#        'KEW GARDENS', 'LEXINGTON AV/53', 'QUEENS PLAZA', 'SPRING ST',
#        'TIMES SQ-42 ST', 'W 4 ST-WASH SQ', 'WORLD TRADE CTR'],
#       dtype=object)

# %%
get_close_matches('TIMES SQUARE-42ND ST' ,stations['station'].unique(), n=5)
# Out:
# ['TIMES SQUARE-42ND ST', 'TIMES SQUARE']

# %% [markdown]
# This above is an example of how the get_close_matches function worked. This was run with all the unique values we had in the df_e dataframe to match the values in the df dataframe.

# %%
conv_station_dict = {
    'TIMES SQUARE-42ND ST': 'TIMES SQ-42 ST', 
    '8TH AV': '8 AV', 
    'SUTPHIN BLVD-ARCHER AV - JFK':'JFK JAMAICA CT1', 
    '42ND ST': '42 ST-PORT AUTH',
    '34TH ST': '34 ST-PENN STA', 
    '23RD ST':'23 ST', 
    '14TH ST':'14 ST', 
    'WEST 4TH ST': 'W 4 ST-WASH SQ', 
    'SPRING ST': 'SPRING ST',
    'CANAL ST': 'CANAL ST', 
    'CHAMBERS ST': 'CHAMBERS ST', 
    'WORLD TRADE CENTER': 'WORLD TRADE CTR', 
    '7TH AV': '7 AV', 
    '5TH AV-53RD ST': '5 AV/53 ST',
    'LEXINGTON AV-53RD ST': 'LEXINGTON AV/53', 
    '45 RD-COURT HOUSE SQ': 'COURT SQ-23 ST', 
    'QUEENS PLAZA': 'QUEENS PLAZA',
    'JACKSON HEIGHTS-ROOSEVELT AVE': 'JKSN HT-ROOSVLT', 
    'FOREST HILLS-71ST AV': 'FOREST HILLS 71', 
    '75TH AV': '75 AV', 
    'KEW GARDENS-UNION TURNPIKE':'KEW GARDENS',
    'JAMAICA-VAN WYCK': 'BRIARWOOD', 
    '50TH ST' : '50 ST'
}

stations['station'] = stations['station'].map(conv_station_dict)

# %%
stations['station'].unique()
# Out:
# array(['14 ST', '23 ST', nan, '34 ST-PENN STA', '42 ST-PORT AUTH',
#        'COURT SQ-23 ST', '50 ST', '5 AV/53 ST', '75 AV', '7 AV', '8 AV',
#        'CANAL ST', 'CHAMBERS ST', 'FOREST HILLS 71', 'JKSN HT-ROOSVLT',
#        'BRIARWOOD', 'KEW GARDENS', 'LEXINGTON AV/53', 'QUEENS PLAZA',
#        'SPRING ST', 'JFK JAMAICA CT1', 'TIMES SQ-42 ST', 'W 4 ST-WASH SQ',
#        'WORLD TRADE CTR'], dtype=object)

# %%
temp_stations = stations.dropna(axis=0, subset=['station'])

# %%
temp_stations.head()
# Out:
#    Station_Latitude  Station_Longitude  Route_8  Route_9  Route_10  Route_11  \
# 0         40.740893         -74.001690      NaN      NaN       NaN       NaN
# 1         40.745906         -73.998041      NaN      NaN       NaN       NaN
# 3         40.752287         -73.993391      NaN      NaN       NaN       NaN
# 4         40.757308         -73.989735      1.0      2.0       3.0       7.0
# 5         40.747023         -73.945264      NaN      NaN       NaN       NaN
#
#    ADA  Free_Crossover   Latitude  Longitude          station  first_closest  \
# 0  1.0             1.0  40.740612 -74.001896            14 ST       0.001861
# 1  0.0             1.0  40.745990 -73.997927            23 ST       0.003181
# 3  1.0             1.0  40.752218 -64.744260   34 ST-PENN STA       0.001281
# 4  1.0             1.0  40.757358 -73.989816  42 ST-PORT AUTH       0.000612
# 5  0.0             1.0  40.746223 -73.945461   COURT SQ-23 ST       0.014239
#
#              first_closest_store  second_closest second_closest_store  \
# 0  8th Ave just south of 14th St        0.002499           19th & 8th
# 1                     24th & 7th        0.003717           19th & 8th
# 3          Penn Station by A,C,E        0.001281       One Penn Plaza
# 4                     42nd & 8th        0.000680    Union Square East
# 5               Roosevelt Island        0.022691         69th & First
#
#    third_closest       third_closest_store
# 0       0.003523  Greenwich Ave at Bank St
# 1       0.003729                23rd & 1st
# 3       0.003779       32nd btwn 6th & 7th
# 4       0.001043                43rd & 8th
# 5       0.023533      35th Ave and 37th St

# %%
temp_stations = temp_stations[['station', 'Station_Latitude', 'Station_Longitude', 'first_closest', 'first_closest_store', 'second_closest', 'second_closest_store', 'third_closest', 'third_closest_store']]

# %%
temp_stations.rename(columns = {'station': 'Station'}, inplace = True)

# %%
temp_stations[temp_stations['Station'] == 'W 4 ST-WASH SQ']
# Out:
#            Station  Station_Latitude  Station_Longitude  first_closest  \
# 27  W 4 ST-WASH SQ         40.732338         -74.000495       0.002392
#
#         first_closest_store  second_closest second_closest_store  \
# 27  7th Ave at Grove Street        0.002569      239 Bleecker St
#
#     third_closest  third_closest_store
# 27       0.005055  New York University

# %%
df_merged =  pd.merge(left = df_e,
        right = temp_stations,
        how ='inner',
        on = 'Station')

# %%
df_merged.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries',
#        'Exits                                                     ',
#        'date_time', 'day', 'month', 'Station_Latitude', 'Station_Longitude',
#        'first_closest', 'first_closest_store', 'second_closest',
#        'second_closest_store', 'third_closest', 'third_closest_store'],
#       dtype='object')

# %%
df_merged.rename(columns = {'Exits                                                     ': 'Exits'}, inplace = True)

# %%
df_merged = df_merged.set_index(['date_time'])

# %%
df_merged.sort_index(inplace = True, ascending = False)

# %%
df_merged.head()
# Out:
#                       C/A  Unit       SCP         Station     Line Name  \
# date_time
# 2017-12-22 23:00:00  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W
# 2017-12-22 23:00:00  N092  R029  03-03-01     CHAMBERS ST         ACE23
# 2017-12-22 23:00:00  N092  R029  03-00-05     CHAMBERS ST         ACE23
# 2017-12-22 23:00:00  R151  R033  00-00-07  TIMES SQ-42 ST  1237ACENQRSW
# 2017-12-22 23:00:00  N092  R029  03-00-04     CHAMBERS ST         ACE23
#
#                     Division        Date      Time Description   Entries  ...  \
# date_time                                                                 ...
# 2017-12-22 23:00:00      BMT  2017-12-22  23:00:00     REGULAR   7357995  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR     51957  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR   2344966  ...
# 2017-12-22 23:00:00      IRT  2017-12-22  23:00:00     REGULAR   1245589  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR  10378155  ...
#
#                         day     month Station_Latitude  Station_Longitude  \
# date_time
# 2017-12-22 23:00:00  Friday  December        40.754672         -73.986754
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
# 2017-12-22 23:00:00  Friday  December        40.754672         -73.986754
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
#
#                      first_closest     first_closest_store second_closest  \
# date_time
# 2017-12-22 23:00:00       0.001214     42nd btwn 3rd & Lex       0.001846
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
# 2017-12-22 23:00:00       0.001214     42nd btwn 3rd & Lex       0.001846
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
#
#                            second_closest_store third_closest  \
# date_time
# 2017-12-22 23:00:00                  39th & 7th      0.002298
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
# 2017-12-22 23:00:00                  39th & 7th      0.002298
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
#
#                            third_closest_store
# date_time
# 2017-12-22 23:00:00  Broadway Btwn 37th & 38th
# 2017-12-22 23:00:00    Broadway at Barclay Str
# 2017-12-22 23:00:00    Broadway at Barclay Str
# 2017-12-22 23:00:00  Broadway Btwn 37th & 38th
# 2017-12-22 23:00:00    Broadway at Barclay Str
#
# [5 rows x 21 columns]

# %% [markdown]
# For some locations, Starbucks is open 24 hours a day. However, normal operations for Starbucks during the week are between 07:00 AM – 11:00 PM. Since most of Starbucks business comes in during the morning time as their primary source of business is coffee, we will filter out the hours to 06:00 AM - 12:00PM.

# %%
df_merged.between_time('06:00:00', '12:00:00')
# Out:
#                        C/A  Unit       SCP          Station Line Name  \
# date_time
# 2017-12-22 12:00:00   N078  R175  01-00-01            14 ST      ACEL
# 2017-12-22 12:00:00  N333B  R141  02-00-01  FOREST HILLS 71      EFMR
# 2017-12-22 12:00:00   N078  R175  01-00-01            14 ST      ACEL
# 2017-12-22 12:00:00  N309A  R140  00-03-00     QUEENS PLAZA       EMR
# 2017-12-22 12:00:00  JFK03  R536  00-00-01  JFK JAMAICA CT1         E
# ...                    ...   ...       ...              ...       ...
# 2016-12-31 07:00:00   N067  R012  00-03-05   34 ST-PENN STA       ACE
# 2016-12-31 07:00:00   N092  R029  03-00-02      CHAMBERS ST     ACE23
# 2016-12-31 07:00:00   N091  R029  02-00-01      CHAMBERS ST     ACE23
# 2016-12-31 07:00:00   N077  R111  02-06-00            23 ST        CE
# 2016-12-31 07:00:00   N090  R139  01-05-00         CANAL ST       ACE
#
#                     Division        Date      Time Description   Entries  ...  \
# date_time                                                                 ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR    557480  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR   1449764  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR    557480  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR     97648  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR    110230  ...
# ...                      ...         ...       ...         ...       ...  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR   4236992  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR  12629825  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR   5992116  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR    988696  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR    584728  ...
#
#                           day     month Station_Latitude  Station_Longitude  \
# date_time
# 2017-12-22 12:00:00    Friday  December        40.740893         -74.001690
# 2017-12-22 12:00:00    Friday  December        40.721691         -73.844521
# 2017-12-22 12:00:00    Friday  December        40.740893         -74.001690
# 2017-12-22 12:00:00    Friday  December        40.748973         -73.937243
# 2017-12-22 12:00:00    Friday  December        40.700486         -73.807969
# ...                       ...       ...              ...                ...
# 2016-12-31 07:00:00  Saturday  December        40.752287         -73.993391
# 2016-12-31 07:00:00  Saturday  December        40.714111         -74.008585
# 2016-12-31 07:00:00  Saturday  December        40.714111         -74.008585
# 2016-12-31 07:00:00  Saturday  December        40.745906         -73.998041
# 2016-12-31 07:00:00  Saturday  December        40.720824         -74.005229
#
#                      first_closest            first_closest_store  \
# date_time
# 2017-12-22 12:00:00       0.001861  8th Ave just south of 14th St
# 2017-12-22 12:00:00       0.001279      107-12 Continental Avenue
# 2017-12-22 12:00:00       0.001861  8th Ave just south of 14th St
# 2017-12-22 12:00:00       0.015421           35th Ave and 37th St
# 2017-12-22 12:00:00       0.003170       89th Ave & Sutphin Blvd.
# ...                            ...                            ...
# 2016-12-31 07:00:00       0.001281          Penn Station by A,C,E
# 2016-12-31 07:00:00       0.000759         Church Street & Murray
# 2016-12-31 07:00:00       0.000759         Church Street & Murray
# 2016-12-31 07:00:00       0.003181                     24th & 7th
# 2016-12-31 07:00:00       0.000901       6th Ave at Walker Street
#
#                     second_closest        second_closest_store third_closest  \
# date_time
# 2017-12-22 12:00:00       0.002499                  19th & 8th      0.003523
# 2017-12-22 12:00:00       0.002948          7000 Austin Street      0.009394
# 2017-12-22 12:00:00       0.002499                  19th & 8th      0.003523
# 2017-12-22 12:00:00       0.017912              31-01 Broadway      0.018468
# 2017-12-22 12:00:00       0.027711          118-24 Queens Blvd      0.028819
# ...                            ...                         ...           ...
# 2016-12-31 07:00:00       0.001281              One Penn Plaza      0.003779
# 2016-12-31 07:00:00       0.001266  Chambers and West Broadway      0.001697
# 2016-12-31 07:00:00       0.001266  Chambers and West Broadway      0.001697
# 2016-12-31 07:00:00       0.003717                  19th & 8th      0.003729
# 2016-12-31 07:00:00       0.002091                222 Broadway      0.003136
#
#                                 third_closest_store
# date_time
# 2017-12-22 12:00:00        Greenwich Ave at Bank St
# 2017-12-22 12:00:00           Queens Blvd & 67th Rd
# 2017-12-22 12:00:00        Greenwich Ave at Bank St
# 2017-12-22 12:00:00                Roosevelt Island
# 2017-12-22 12:00:00  St. John's University - Queens
# ...                                             ...
# 2016-12-31 07:00:00             32nd btwn 6th & 7th
# 2016-12-31 07:00:00         Broadway at Barclay Str
# 2016-12-31 07:00:00         Broadway at Barclay Str
# 2016-12-31 07:00:00                      23rd & 1st
# 2016-12-31 07:00:00                Broadway & Canal
#
# [267839 rows x 21 columns]

# %%
df_merged.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries', 'Exits', 'day', 'month',
#        'Station_Latitude', 'Station_Longitude', 'first_closest',
#        'first_closest_store', 'second_closest', 'second_closest_store',
#        'third_closest', 'third_closest_store'],
#       dtype='object')

# %%
df_merged.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries', 'Exits', 'day', 'month',
#        'Station_Latitude', 'Station_Longitude', 'first_closest',
#        'first_closest_store', 'second_closest', 'second_closest_store',
#        'third_closest', 'third_closest_store'],
#       dtype='object')

# %%
df= (df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station','Line Name', 'Division', 'Date','month', 'day', 'Station_Latitude', 'Station_Longitude', 'first_closest',
                   'first_closest_store','second_closest', 'second_closest_store','third_closest',
                   'third_closest_store'])['Entries'].max() 
 - df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station','Line Name', 'Division','Date','month', 'day', 'Station_Latitude', 'Station_Longitude','first_closest',
                     'first_closest_store','second_closest', 'second_closest_store','third_closest',
                     'third_closest_store'])['Entries'].min()).reset_index()

# %%
exits = (df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division','Date','month', 'day', 'first_closest',
                   'first_closest_store','second_closest', 'second_closest_store','third_closest',
                   'third_closest_store'])['Exits'].max() 
 - df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station','Line Name', 'Division','Date','month', 'day','first_closest',
                     'first_closest_store','second_closest', 'second_closest_store','third_closest',
                     'third_closest_store'])['Exits'].min()).reset_index()

# %%
exits.head()
# Out:
#     C/A  Unit       SCP         Station     Line Name Division        Date  \
# 0  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2016-12-31
# 1  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-01
# 2  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-02
# 3  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-03
# 4  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-04
#
#       month        day  first_closest  first_closest_store  second_closest  \
# 0  December   Saturday       0.001214  42nd btwn 3rd & Lex        0.001846
# 1   January     Sunday       0.001214  42nd btwn 3rd & Lex        0.001846
# 2   January     Monday       0.001214  42nd btwn 3rd & Lex        0.001846
# 3   January    Tuesday       0.001214  42nd btwn 3rd & Lex        0.001846
# 4   January  Wednesday       0.001214  42nd btwn 3rd & Lex        0.001846
#
#   second_closest_store  third_closest        third_closest_store  Exits
# 0           39th & 7th       0.002298  Broadway Btwn 37th & 38th   1607
# 1           39th & 7th       0.002298  Broadway Btwn 37th & 38th   1568
# 2           39th & 7th       0.002298  Broadway Btwn 37th & 38th   1808
# 3           39th & 7th       0.002298  Broadway Btwn 37th & 38th   3895
# 4           39th & 7th       0.002298  Broadway Btwn 37th & 38th   4108

# %%
df['Exits'] = exits['Exits']

# %%
df.head()
# Out:
#     C/A  Unit       SCP         Station     Line Name Division        Date  \
# 0  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2016-12-31
# 1  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-01
# 2  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-02
# 3  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-03
# 4  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-04
#
#       month        day  Station_Latitude  Station_Longitude  first_closest  \
# 0  December   Saturday         40.754672         -73.986754       0.001214
# 1   January     Sunday         40.754672         -73.986754       0.001214
# 2   January     Monday         40.754672         -73.986754       0.001214
# 3   January    Tuesday         40.754672         -73.986754       0.001214
# 4   January  Wednesday         40.754672         -73.986754       0.001214
#
#    first_closest_store  second_closest second_closest_store  third_closest  \
# 0  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 1  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 2  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 3  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 4  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
#
#          third_closest_store  Entries  Exits
# 0  Broadway Btwn 37th & 38th      622   1607
# 1  Broadway Btwn 37th & 38th      767   1568
# 2  Broadway Btwn 37th & 38th     1192   1808
# 3  Broadway Btwn 37th & 38th     3193   3895
# 4  Broadway Btwn 37th & 38th     3124   4108

# %%
df.dtypes
# Out:
# C/A                      object
# Unit                     object
# SCP                      object
# Station                  object
# Line Name                object
# Division                 object
# Date                     object
# month                    object
# day                      object
# Station_Latitude        float64
# Station_Longitude       float64
# first_closest           float64
# first_closest_store      object
# second_closest          float64
# second_closest_store     object
# third_closest           float64
# third_closest_store      object
# Entries                   int64
# Exits                     int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# C/A                             object
# Unit                            object
# SCP                             object
# Station                         object
# Line Name                       object
# Division                        object
# Date                    datetime64[ns]
# month                           object
# day                             object
# Station_Latitude               float64
# Station_Longitude              float64
# first_closest                  float64
# first_closest_store             object
# second_closest                 float64
# second_closest_store            object
# third_closest                  float64
# third_closest_store             object
# Entries                          int64
# Exits                            int64
# dtype: object

# %%
df = df.set_index(['Date'])

# %%
df['Entries'].sort_values().tail(20)
# Out:
# Date
# 2017-12-19       5379758
# 2017-06-22       5449929
# 2017-12-01       8224299
# 2017-07-04       8266473
# 2017-11-30      11007391
# 2017-09-27      11781823
# 2017-03-02      14180769
# 2017-07-23      16594428
# 2017-09-01      21566536
# 2017-03-06      36107735
# 2017-03-07      36110538
# 2017-01-08      50330602
# 2017-01-03      66562129
# 2017-03-07      99848623
# 2017-01-09     117440381
# 2017-06-17     150102672
# 2017-08-27     735329800
# 2017-01-26    1153072639
# 2017-08-09    1211446878
# 2017-12-19    1579485694
# Name: Entries, dtype: int64

# %%
df = df[(df['Entries'] < 30000) & (df['Entries'] < 30000) ]

# %%
df['Entries'].sort_values().tail(20)
# Out:
# Date
# 2017-07-15     7294
# 2017-07-15     7591
# 2017-07-08     7609
# 2017-07-15     7641
# 2017-08-07     7799
# 2017-08-01     8177
# 2017-08-09     8259
# 2017-08-08     8318
# 2017-07-08     8440
# 2017-08-04     8607
# 2017-08-03     8615
# 2017-08-10     8721
# 2017-10-15    13783
# 2017-06-15    17058
# 2017-12-19    18945
# 2017-09-19    22133
# 2017-08-26    23347
# 2017-10-22    29355
# 2017-04-12    29581
# 2017-09-30    29697
# Name: Entries, dtype: int64

# %%
(df['Exits'].sort_values().tail(20))
# Out:
# Date
# 2017-02-28     9783
# 2017-10-15     9800
# 2017-12-14     9833
# 2017-03-03     9833
# 2017-02-03     9842
# 2017-04-25     9849
# 2017-02-17     9875
# 2017-03-02     9904
# 2017-02-13    10003
# 2017-08-07    10027
# 2017-11-10    10104
# 2017-12-15    10191
# 2017-02-16    10204
# 2017-11-07    10954
# 2017-09-19    11514
# 2017-10-22    15716
# 2017-06-15    22306
# 2017-08-26    32009
# 2017-04-12    34678
# 2017-09-30    38249
# Name: Exits, dtype: int64

# %%
df = df[(df['Exits'] < 30000) & (df['Exits'] < 30000) ]

# %%
df['Exits'].sort_values().tail(20)
# Out:
# Date
# 2017-02-14     9690
# 2017-11-30     9709
# 2017-11-17     9716
# 2017-02-28     9783
# 2017-10-15     9800
# 2017-12-14     9833
# 2017-03-03     9833
# 2017-02-03     9842
# 2017-04-25     9849
# 2017-02-17     9875
# 2017-03-02     9904
# 2017-02-13    10003
# 2017-08-07    10027
# 2017-11-10    10104
# 2017-12-15    10191
# 2017-02-16    10204
# 2017-11-07    10954
# 2017-09-19    11514
# 2017-10-22    15716
# 2017-06-15    22306
# Name: Exits, dtype: int64

# %%
df.head()
# Out:
#              C/A  Unit       SCP         Station     Line Name Division  \
# Date
# 2016-12-31  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-01  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-02  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-03  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-04  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#                month        day  Station_Latitude  Station_Longitude  \
# Date
# 2016-12-31  December   Saturday         40.754672         -73.986754
# 2017-01-01   January     Sunday         40.754672         -73.986754
# 2017-01-02   January     Monday         40.754672         -73.986754
# 2017-01-03   January    Tuesday         40.754672         -73.986754
# 2017-01-04   January  Wednesday         40.754672         -73.986754
#
#             first_closest  first_closest_store  second_closest  \
# Date
# 2016-12-31       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-01       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-02       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-03       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-04       0.001214  42nd btwn 3rd & Lex        0.001846
#
#            second_closest_store  third_closest        third_closest_store  \
# Date
# 2016-12-31           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-01           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-02           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-03           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-04           39th & 7th       0.002298  Broadway Btwn 37th & 38th
#
#             Entries  Exits
# Date
# 2016-12-31      622   1607
# 2017-01-01      767   1568
# 2017-01-02     1192   1808
# 2017-01-03     3193   3895
# 2017-01-04     3124   4108

# %%
df.describe()
# Out:
#        Station_Latitude  Station_Longitude  first_closest  second_closest  \
# count     113675.000000      113675.000000  113675.000000   113675.000000
# mean          40.741380         -73.957838       0.003676        0.005937
# std            0.018615           0.060424       0.006662        0.008731
# min           40.700486         -74.009781       0.000381        0.000680
# 25%           40.721691         -73.993391       0.000759        0.001281
# 50%           40.748973         -73.986754       0.001279        0.001827
# 75%           40.757308         -73.937243       0.002392        0.003717
# max           40.762862         -73.807969       0.030072        0.033464
#
#        third_closest        Entries          Exits
# count  113675.000000  113675.000000  113675.000000
# mean        0.007486    1123.900163     920.364724
# std         0.009356    1001.653783    1090.153688
# min         0.001043       0.000000       0.000000
# 25%         0.001915     348.000000     182.000000
# 50%         0.003136     918.000000     587.000000
# 75%         0.009394    1645.000000    1197.000000
# max         0.035837   29355.000000   22306.000000

# %% [markdown]
# ## Featured Engineering

# %%
df['total_turns'] = df['Entries'] + df['Exits']

# %%
df['avg_distance'] = df['first_closest'] * df['second_closest'] * df['third_closest']

# %% [markdown]
# ## Graph EDA

# %%
df.head()
# Out:
#              C/A  Unit       SCP         Station     Line Name Division  \
# Date
# 2016-12-31  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-01  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-02  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-03  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-04  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#                month        day  Station_Latitude  Station_Longitude  \
# Date
# 2016-12-31  December   Saturday         40.754672         -73.986754
# 2017-01-01   January     Sunday         40.754672         -73.986754
# 2017-01-02   January     Monday         40.754672         -73.986754
# 2017-01-03   January    Tuesday         40.754672         -73.986754
# 2017-01-04   January  Wednesday         40.754672         -73.986754
#
#             first_closest  first_closest_store  second_closest  \
# Date
# 2016-12-31       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-01       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-02       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-03       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-04       0.001214  42nd btwn 3rd & Lex        0.001846
#
#            second_closest_store  third_closest        third_closest_store  \
# Date
# 2016-12-31           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-01           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-02           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-03           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-04           39th & 7th       0.002298  Broadway Btwn 37th & 38th
#
#             Entries  Exits  total_turns  avg_distance
# Date
# 2016-12-31      622   1607         2229  5.150430e-09
# 2017-01-01      767   1568         2335  5.150430e-09
# 2017-01-02     1192   1808         3000  5.150430e-09
# 2017-01-03     3193   3895         7088  5.150430e-09
# 2017-01-04     3124   4108         7232  5.150430e-09

# %%
plt.figure(figsize=(20, 8))
sns.lineplot(x =temp.index, y = temp.total_turns, hue = temp.Station)

# %%
len(df.groupby(['Station'])['total_turns'].sum())
# Out:
# 23

# %%
stations_names = df['Station'].sort_values().unique()
stations_names
# Out:
# array(['14 ST', '23 ST', '34 ST-PENN STA', '42 ST-PORT AUTH',
#        '5 AV/53 ST', '50 ST', '7 AV', '75 AV', '8 AV', 'BRIARWOOD',
#        'CANAL ST', 'CHAMBERS ST', 'COURT SQ-23 ST', 'FOREST HILLS 71',
#        'JFK JAMAICA CT1', 'JKSN HT-ROOSVLT', 'KEW GARDENS',
#        'LEXINGTON AV/53', 'QUEENS PLAZA', 'SPRING ST', 'TIMES SQ-42 ST',
#        'W 4 ST-WASH SQ', 'WORLD TRADE CTR'], dtype=object)

# %%
plt.figure(figsize=(10, 8))

df.groupby(['Station'])['total_turns'].sum().sort_values().plot(kind = 'barh', colors = 'blue', edgecolor='black',
                                                               linewidth='3')
plt.title('Total Entries per Station(In Tens of Millions)',fontsize = 20)
plt.xlabel('Total Turns', fontsize = 15)
plt.ylabel('Month',fontsize = 15)
plt.legend(fontsize = 15);

# %%
plt.figure(figsize=(10, 8))

df.groupby(['Station'])['avg_distance'].mean().sort_values().plot(kind = 'barh', colors = 'green', edgecolor='black',
                                                               linewidth='3')
plt.title('Average Distance of 3 Closest Starbuck to Station',fontsize = 20)
plt.xlabel('Average Distance of 3 Closest Stores', fontsize = 15)
plt.ylabel('Station',fontsize = 15)
plt.legend(fontsize = 15,loc = 'lower right');

# %%
# Have two sets of data we want to plot
bars1 = df.groupby(['Station'])['total_turns'].sum()
bars2 = df.groupby(['Station'])['avg_distance'].mean()

# arange x values to be plotted
b1 = np.arange(len(bars1))
b2 = [x + barWidth for x in b1]
b3 = b1+b2 

#Set up Graph
fig = plt.figure(figsize = (15,8))
ax = plt.subplot(111)
barWidth = 0.3

# Create Total Turns bar
ax.bar(b1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', capsize=7, label='Turns (in Millions)')
plt.xticks([r + barWidth for r in range(len(b3))], stations_names, rotation=45,fontsize = 15)
plt.setp(ax.xaxis.get_majorticklabels(), ha='right')
plt.yticks(fontsize = 10)
plt.ylabel('Total Turns (In Tens of Millions)', fontsize = 20)
# Create Starbucks Distance
ax2 = ax.twinx()
ax2.bar(b2, bars2, width = barWidth, color = 'green', edgecolor = 'black', capsize=7, label='Starbucks Distance')
plt.ylabel('Distance', fontsize = 20)

plt.title("Total Turns and Distance",  fontsize= 25)
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0, fontsize = 15)

plt.show()

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September',
          'October', 'November', 'December']

# %%
reversed(months)

# %%
df.groupby(['month'])['total_turns'].sum()[months]
# Out:
# month
# January      21842140
# February     16262044
# March        18537504
# April        21421738
# May          23309987
# June         12249956
# July         21177476
# August       22071261
# September    16811844
# October      23453017
# November     22986653
# December     12258191
# Name: total_turns, dtype: int64

# %%
plt.figure(figsize=(10, 8))

df.groupby(['month'])['total_turns'].sum()[reversed(months)].plot(kind = 'barh', colors = 'blue', edgecolor='black',
                                                               linewidth='3')
plt.title('Total Entries per Month(In Tens of Millions)',fontsize = 20)
plt.xlabel('Total Turns', fontsize = 15)
plt.ylabel('Month',fontsize = 15)
# Out:
# Text(0, 0.5, 'Month')

# %%
day = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday']

# %%
plt.figure(figsize=(10, 8))

df.groupby(['day'])['total_turns'].sum()[reversed(day)].plot(kind = 'barh', colors = 'blue', edgecolor='black',
                                                               linewidth='3')
plt.title('Total Entries per Month(In Tens of Millions)',fontsize = 20)
plt.xlabel('Total Turns', fontsize = 15)
plt.ylabel('day',fontsize = 15)
# Out:
# Text(0, 0.5, 'day')

# %%
fol = df.groupby('Station').mean().reset_index()
fol2 = df.groupby('Station').sum().reset_index()
fol.head()
# Out:
#            Station  Station_Latitude  Station_Longitude  first_closest  \
# 0            14 ST         40.740893         -74.001690       0.001861
# 1            23 ST         40.745906         -73.998041       0.003181
# 2   34 ST-PENN STA         40.752287         -73.993391       0.001281
# 3  42 ST-PORT AUTH         40.757308         -73.989735       0.000612
# 4       5 AV/53 ST         40.760167         -73.975224       0.001516
#
#    second_closest  third_closest      Entries        Exits  total_turns  \
# 0        0.002499       0.003523  1586.097179  2408.758621  3994.855799
# 1        0.003717       0.003729  1204.652737   833.162919  2037.815655
# 2        0.001281       0.003779  1136.768325  1082.399700  2219.168024
# 3        0.000680       0.001043  1587.264095  1140.270447  2727.534542
# 4        0.001719       0.001915   909.374301  1011.256085  1920.630385
#
#    avg_distance
# 0  1.638377e-08
# 1  4.408462e-08
# 2  6.205325e-09
# 3  4.339208e-10
# 4  4.990736e-09

# %%
lat = [coors for coors in fol['Station_Latitude']]
long = [coors for coors in fol['Station_Longitude']]
coors = (pd.DataFrame({'lat': lat,'long':long}))
points = list(zip(coors['lat'], coors['long']))

# %%
m = folium.Map(location=[40.693943, -73.985880], default_zoom_start=10)

for i in range(0,len(fol)):
    folium.Circle(
        location=[fol.iloc[i]['Station_Latitude'], fol.iloc[i]['Station_Longitude']],
        popup=fol.iloc[i]['Station'],
        radius=fol2.iloc[i]['total_turns']/90000,
        color='crimson',
        fill=True,
        fill_color='crimson'
   ).add_to(m)
    folium.Marker(
        location=[fol.iloc[i]['Station_Latitude'], fol.iloc[i]['Station_Longitude']],
        popup=fol.iloc[i]['Station'],
        tooltip = "Station"
   ).add_to(m)
    
m

# %% [markdown]
# http://web.mta.info/nyct/service/eline.htm

# %% [markdown]
# ### Port Authority

# %%
df.head()
# Out:
#              C/A  Unit       SCP         Station     Line Name Division  \
# Date
# 2016-12-31  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-01  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-02  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-03  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-04  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#                month        day  Station_Latitude  Station_Longitude  \
# Date
# 2016-12-31  December   Saturday         40.754672         -73.986754
# 2017-01-01   January     Sunday         40.754672         -73.986754
# 2017-01-02   January     Monday         40.754672         -73.986754
# 2017-01-03   January    Tuesday         40.754672         -73.986754
# 2017-01-04   January  Wednesday         40.754672         -73.986754
#
#             first_closest  first_closest_store  second_closest  \
# Date
# 2016-12-31       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-01       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-02       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-03       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-04       0.001214  42nd btwn 3rd & Lex        0.001846
#
#            second_closest_store  third_closest        third_closest_store  \
# Date
# 2016-12-31           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-01           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-02           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-03           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-04           39th & 7th       0.002298  Broadway Btwn 37th & 38th
#
#             Entries  Exits  total_turns  avg_distance
# Date
# 2016-12-31      622   1607         2229  5.150430e-09
# 2017-01-01      767   1568         2335  5.150430e-09
# 2017-01-02     1192   1808         3000  5.150430e-09
# 2017-01-03     3193   3895         7088  5.150430e-09
# 2017-01-04     3124   4108         7232  5.150430e-09

# %%
port = df[df['Station'] == '42 ST-PORT AUTH']

# %%
plt.figure(figsize=(24,10))
port['Entries'].plot()

# %%
plt.figure(figsize=(10, 8))
port.groupby('day')['Entries'].sum()[reversed(day)].plot(kind = 'barh', colors = 'blue', edgecolor='black',
                                                               linewidth='3')
plt.title('Port Authority Turns by Day of Week', fontsize = 20)
plt.xlabel('Total Entries', fontsize = 15)
plt.ylabel('Day of Week', fontsize = 15)
# Out:
# Text(0, 0.5, 'Day of Week')

# %%
port1 = df.loc[df['Station'] == '42 ST-PORT AUTH',:].groupby('Date').sum()

# %%
port1
# Out:
#             Station_Latitude  Station_Longitude  first_closest  \
# Date
# 2016-12-31       1997.108092       -3625.497015       0.029978
# 2017-01-01       1997.108092       -3625.497015       0.029978
# 2017-01-02       1997.108092       -3625.497015       0.029978
# 2017-01-03       1997.108092       -3625.497015       0.029978
# 2017-01-04       1997.108092       -3625.497015       0.029978
# ...                      ...                ...            ...
# 2017-12-18       1956.350784       -3551.507280       0.029366
# 2017-12-19       1956.350784       -3551.507280       0.029366
# 2017-12-20       1956.350784       -3551.507280       0.029366
# 2017-12-21       1956.350784       -3551.507280       0.029366
# 2017-12-22       1956.350784       -3551.507280       0.029366
#
#             second_closest  third_closest  Entries  Exits  total_turns  \
# Date
# 2016-12-31        0.033334       0.051087    64566  45238       109804
# 2017-01-01        0.033334       0.051087    48202  37811        86013
# 2017-01-02        0.033334       0.051087    53122  38180        91302
# 2017-01-03        0.033334       0.051087    95763  64798       160561
# 2017-01-04        0.033334       0.051087    93185  62397       155582
# ...                    ...            ...      ...    ...          ...
# 2017-12-18        0.032653       0.050044    91165  61849       153014
# 2017-12-19        0.032653       0.050044    90191  62946       153137
# 2017-12-20        0.032653       0.050044    90403  64067       154470
# 2017-12-21        0.032653       0.050044    88780  67421       156201
# 2017-12-22        0.032653       0.050044    79494  59098       138592
#
#             avg_distance
# Date
# 2016-12-31  2.126212e-08
# 2017-01-01  2.126212e-08
# 2017-01-02  2.126212e-08
# 2017-01-03  2.126212e-08
# 2017-01-04  2.126212e-08
# ...                  ...
# 2017-12-18  2.082820e-08
# 2017-12-19  2.082820e-08
# 2017-12-20  2.082820e-08
# 2017-12-21  2.082820e-08
# 2017-12-22  2.082820e-08
#
# [315 rows x 9 columns]

# %%
plt.figure(figsize=(24,10))
port1['total_turns'].plot()

# %%
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    
    # Iterate through each column name.
    for col in cols:
            
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18, rotation = 45);

# %%
plot_series(port1.resample('M', closed = 'left').mean(),
            ['total_turns'],
            title = 'Average Entries',
            steps = 1)

# %%
port1 = port1.resample('M', closed = 'left').mean()

# %%
port1['rolling_week_turns'] = port1['total_turns'].rolling(7).mean()
port1['rolling_month_turns'] = port1['total_turns'].rolling(30).mean()
port1['rolling_quarter_turns'] = port1['total_turns'].rolling(91).mean()

# %%
plt.figure(figsize = (10,8))
port1['rolling_week_turns'].plot()
port1['rolling_month_turns'].plot()
port1['rolling_quarter_turns'].plot()
plt.title('Rolling Turns', fontsize = 20)
plt.xlabel('Turns', fontsize = 15)
plt.ylabel('Date', fontsize = 15)
plt.legend(loc='upper center', bbox_to_anchor=(1.2, .9), shadow=True, ncol=1);

# %%
port1['auto_1_week'] = port1['total_turns'].shift(1)
port1['auto_1_month'] = port1['total_turns'].shift(4)
port1['auto_1_year'] = port1['total_turns'].shift(52)

# %%
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(211)
fig = plot_acf(port1['total_turns'], lags=10, ax=ax1);

# %%
port1[['total_turns','auto_1_week', 'auto_1_month', 'auto_1_year']].corr()
# Out:
#               total_turns  auto_1_week  auto_1_month  auto_1_year
# total_turns      1.000000    -0.376222     -0.211937          NaN
# auto_1_week     -0.376222     1.000000      0.001135          NaN
# auto_1_month    -0.211937     0.001135      1.000000          NaN
# auto_1_year           NaN          NaN           NaN          NaN

# %%
print(f'Autocorrelation between Total Turns and 1-lag Total Turns: {round(port1["total_turns"].autocorr(lag=1),4)}')
print(f'Autocorrelation between Total Turns and 2-lag Total Turns: {round(port1["total_turns"].autocorr(lag=2),4)}')
print(f'Autocorrelation between Total Turns and 52-lag Total Turns: {round(port1["total_turns"].autocorr(lag=52),4)}')
# Out:
# Autocorrelation between Total Turns and 1-lag Total Turns: -0.3762
# Autocorrelation between Total Turns and 2-lag Total Turns: -0.042
# Autocorrelation between Total Turns and 52-lag Total Turns: nan

# %%
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(211)
fig = plot_pacf(port1['total_turns'], lags=12, ax=ax1);

# %%
port1 = df.loc[df['Station'] == '42 ST-PORT AUTH',:].groupby('Date').sum()

# %%
port1.shape
# Out:
# (315, 9)

# %%
port1.head()
# Out:
#             Station_Latitude  Station_Longitude  first_closest  \
# Date
# 2016-12-31       1997.108092       -3625.497015       0.029978
# 2017-01-01       1997.108092       -3625.497015       0.029978
# 2017-01-02       1997.108092       -3625.497015       0.029978
# 2017-01-03       1997.108092       -3625.497015       0.029978
# 2017-01-04       1997.108092       -3625.497015       0.029978
#
#             second_closest  third_closest  Entries  Exits  total_turns  \
# Date
# 2016-12-31        0.033334       0.051087    64566  45238       109804
# 2017-01-01        0.033334       0.051087    48202  37811        86013
# 2017-01-02        0.033334       0.051087    53122  38180        91302
# 2017-01-03        0.033334       0.051087    95763  64798       160561
# 2017-01-04        0.033334       0.051087    93185  62397       155582
#
#             avg_distance
# Date
# 2016-12-31  2.126212e-08
# 2017-01-01  2.126212e-08
# 2017-01-02  2.126212e-08
# 2017-01-03  2.126212e-08
# 2017-01-04  2.126212e-08

# %% [markdown]
# ## Modelings

# %% [markdown]
# For our modeling stage, we are going to look to fit an ARIMA as well as an SARIMAX model to judge on.

# %%
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# %%
interpret_dftest(adfuller(port1['total_turns']))
# Out:
# Test Statistic   -4.673698
# p-value           0.000094
# dtype: float64

# %%
port1['total_turns_diff1'] = port1['total_turns'].diff(1)

# %%
port1['total_turns_diff1'].dropna(inplace = True)

# %%
interpret_dftest(adfuller(port1['total_turns_diff1']))
# Out:
# Test Statistic   -4.089659
# p-value           0.001007
# dtype: float64

# %%
train, test = train_test_split(port1['total_turns'], test_size = 0.25, shuffle = False)

# %%
def train_test_plot(train, test):
    plt.figure(figsize=(16, 8))
    plt.plot(train, c='blue')
    plt.plot(test, c='orange');

# %% [markdown]
# ### ARIMA

# %%
len(train)
# Out:
# 236

# %%
len(test)
# Out:
# 79

# %%
train_test_plot(train, test)

# %%
# Starting AIC, p, and q.
best_aic = 99 * (10 ** 16)
best_p = 0
best_q = 0

# Use nested for loop to iterate over values of p and q.
for p in range (5):
    for q in range (5):
        
        
        # Insert try and except statements.
        try:
            
            # Fitting an ARIMA(p, 0, q) model.
            print(f'Attempting to fit ARIMA({p}, 0, {q}) Model')
            
            # Instantiate ARIMA model.
            arima = ARIMA(endog = train.astype(float).dropna(),  ##endog = y - variable
                         order = (p, 0, q))
            
            # Fit ARIMA model.
            model = arima.fit()

            # Print out AIC for ARIMA(p, 1, q) model.
            print(f'The AIC for ARIMA({p},1,{q}) is: {model.aic}')

            # Is my current model's AIC better than our best_aic?
            if model.aic < best_aic:
                
                # If so, let's overwrite best_aic, best_p, and best_q.
                best_aic = model.aic
                best_p = p
                best_q = q

        except:
            pass
print()
print()
print('MODEL FINISHED!')
print(f'Our model that minimizes AIC on the training data is the ARIMA({best_p},0,{best_q}).')
print(f'This model has an AIC of {best_aic}.')
# Out:
# Attempting to fit ARIMA(0, 0, 0) Model
# The AIC for ARIMA(0,1,0) is: 5572.484065568603
# Attempting to fit ARIMA(0, 0, 1) Model
# The AIC for ARIMA(0,1,1) is: 5529.778056775479
# Attempting to fit ARIMA(0, 0, 2) Model
# The AIC for ARIMA(0,1,2) is: 5515.090096420732
# Attempting to fit ARIMA(0, 0, 3) Model
# The AIC for ARIMA(0,1,3) is: 5481.78144855227
# Attempting to fit ARIMA(0, 0, 4) Model
# Attempting to fit ARIMA(1, 0, 0) Model
# The AIC for ARIMA(1,1,0) is: 5552.530461394445
# Attempting to fit ARIMA(1, 0, 1) Model
# The AIC for ARIMA(1,1,1) is: 5529.984185711405
# Attempting to fit ARIMA(1, 0, 2) Model
# The AIC for ARIMA(1,1,2) is: 5495.021126689071
# Attempting to fit ARIMA(1, 0, 3) Model
# The AIC for ARIMA(1,1,3) is: 5483.764526424297
# Attempting to fit ARIMA(1, 0, 4) Model
# The AIC for ARIMA(1,1,4) is: 5480.487696418872
# Attempting to fit ARIMA(2, 0, 0) Model
# The AIC for ARIMA(2,1,0) is: 5507.906837114937
# Attempting to fit ARIMA(2, 0, 1) Model
# The AIC for ARIMA(2,1,1) is: 5470.064681255259
# Attempting to fit ARIMA(2, 0, 2) Model
# The AIC for ARIMA(2,1,2) is: 5381.4196411209705
# Attempting to fit ARIMA(2, 0, 3) Model
# The AIC for ARIMA(2,1,3) is: 5371.095640705754
# Attempting to fit ARIMA(2, 0, 4) Model
# The AIC for ARIMA(2,1,4) is: 5357.213024967143
# Attempting to fit ARIMA(3, 0, 0) Model
# The AIC for ARIMA(3,1,0) is: 5500.712309264695
# Attempting to fit ARIMA(3, 0, 1) Model
# The AIC for ARIMA(3,1,1) is: 5470.259635853442
# Attempting to fit ARIMA(3, 0, 2) Model
# The AIC for ARIMA(3,1,2) is: 5379.0823383650995
# Attempting to fit ARIMA(3, 0, 3) Model
# The AIC for ARIMA(3,1,3) is: 5378.208899836607
# Attempting to fit ARIMA(3, 0, 4) Model
# The AIC for ARIMA(3,1,4) is: 5350.597550330317
# Attempting to fit ARIMA(4, 0, 0) Model
# The AIC for ARIMA(4,1,0) is: 5457.695368718372
# Attempting to fit ARIMA(4, 0, 1) Model
# The AIC for ARIMA(4,1,1) is: 5439.549501897499
# Attempting to fit ARIMA(4, 0, 2) Model
# The AIC for ARIMA(4,1,2) is: 5330.524587206782
# Attempting to fit ARIMA(4, 0, 3) Model
# The AIC for ARIMA(4,1,3) is: 5329.454287042628
# Attempting to fit ARIMA(4, 0, 4) Model
# The AIC for ARIMA(4,1,4) is: 5234.0422193641425
#
#
# MODEL FINISHED!
# Our model that minimizes AIC on the training data is the ARIMA(4,0,4).
# This model has an AIC of 5234.0422193641425.

# %%
train_date= train.index

# %%
best_arima = ARIMA(endog = train.astype(float),
              order = (4, 0, 4))
best_arima_fit = best_arima.fit()

# %%
test.index[0]
# Out:
# Timestamp('2017-09-28 00:00:00')

# %%
test.index[-1]
# Out:
# Timestamp('2017-12-22 00:00:00')

# %%
preds = best_arima_fit.forecast(steps = len(test))[0]

# %%
len(preds)
# Out:
# 79

# %%
arima_error = np.sqrt(mean_squared_error(test, preds))
print(f'RMSE: {round(arima_error, 2)}')
# Out:
# RMSE: 16828.39

# %% [markdown]
# ### Sarmimax

# %%
# Starting AIC, p, and q.
best_rmse = 99 * (10 ** 16)
best_P = 0
best_D = 0
best_Q = 0
#best D- when looking at sarimax
# Use nested for loop to iterate over values of P, D and Q.
for P in range (4):
    for D in range (4):
        for Q in range (4):


        
        # Insert try and except statements.
            try:

                # Fitting an ASARIMAX (P, D, Q, 12) model.
                print(f'Attempting to fit SARIMAX({P}, {D}, {Q}, 12) Model')

                # Instantiate ARIMA model.
                sarimax = SARIMAX(endog = train.astype(float).dropna(),  ##endog = y - variable
                                  order = (4,0,4),
                                  seasonal_order = (P, D, Q, 12))
                    #instead of arima, its SARIMAX        
                    #seasonal order, (P,D,Q,12) 12 is also S
                # Fit ARIMA model.
                model = sarimax.fit()

                sarimax_pred =  model.forecast(steps = len(test))[0]
                # Print out AIC for SARIMAX(P, D, Q,12) model.
                # Evaluate predictions.
                print(f'The RMSE for (0, 1, 1)x({P},{D},{Q},12) is: {np.sqrt(mean_squared_error(test, sarimax_pred)), preds}')
                # Is my current model's RMSE better than our best_RMSE?
                if np.sqrt(mean_squared_error(test, sarimax_pred)) < final_rmse:

                    # If so, let's overwrite best_RMSE best_p, and best_q.
                    final_rmse = np.sqrt(mean_squared_error(test, sarimax_pred))
                    best_P = P
                    best_D = D
                    best_Q = Q
            except:
                pass
print()
print()
print('MODEL FINISHED!')
print(f'Our model that minimizes AIC on the training data is the SARIMAX({best_P},{best_D},{best_Q}, 12).')
print(f'This model has an AIC of {final_rmse}.')
# Out:
# Attempting to fit SARIMAX(0, 0, 0, 12) Model
# Attempting to fit SARIMAX(0, 0, 1, 12) Model
# Attempting to fit SARIMAX(0, 0, 2, 12) Model
# Attempting to fit SARIMAX(0, 0, 3, 12) Model
# Attempting to fit SARIMAX(0, 1, 0, 12) Model
# Attempting to fit SARIMAX(0, 1, 1, 12) Model
# Attempting to fit SARIMAX(0, 1, 2, 12) Model
# Attempting to fit SARIMAX(0, 1, 3, 12) Model
# Attempting to fit SARIMAX(0, 2, 0, 12) Model
# Attempting to fit SARIMAX(0, 2, 1, 12) Model
# Attempting to fit SARIMAX(0, 2, 2, 12) Model
# Attempting to fit SARIMAX(0, 2, 3, 12) Model
# Attempting to fit SARIMAX(0, 3, 0, 12) Model
# Attempting to fit SARIMAX(0, 3, 1, 12) Model
# Attempting to fit SARIMAX(0, 3, 2, 12) Model
# Attempting to fit SARIMAX(0, 3, 3, 12) Model
# Attempting to fit SARIMAX(1, 0, 0, 12) Model
# Attempting to fit SARIMAX(1, 0, 1, 12) Model
# Attempting to fit SARIMAX(1, 0, 2, 12) Model
# Attempting to fit SARIMAX(1, 0, 3, 12) Model
# Attempting to fit SARIMAX(1, 1, 0, 12) Model
# Attempting to fit SARIMAX(1, 1, 1, 12) Model
# Attempting to fit SARIMAX(1, 1, 2, 12) Model
# Attempting to fit SARIMAX(1, 1, 3, 12) Model
# Attempting to fit SARIMAX(1, 2, 0, 12) Model
# Attempting to fit SARIMAX(1, 2, 1, 12) Model
# Attempting to fit SARIMAX(1, 2, 2, 12) Model
# Attempting to fit SARIMAX(1, 2, 3, 12) Model
# Attempting to fit SARIMAX(1, 3, 0, 12) Model
# Attempting to fit SARIMAX(1, 3, 1, 12) Model
# Attempting to fit SARIMAX(1, 3, 2, 12) Model
# Attempting to fit SARIMAX(1, 3, 3, 12) Model
# Attempting to fit SARIMAX(2, 0, 0, 12) Model
# Attempting to fit SARIMAX(2, 0, 1, 12) Model
# Attempting to fit SARIMAX(2, 0, 2, 12) Model
# Attempting to fit SARIMAX(2, 0, 3, 12) Model
# Attempting to fit SARIMAX(2, 1, 0, 12) Model
# Attempting to fit SARIMAX(2, 1, 1, 12) Model
# Attempting to fit SARIMAX(2, 1, 2, 12) Model
# Attempting to fit SARIMAX(2, 1, 3, 12) Model
# Attempting to fit SARIMAX(2, 2, 0, 12) Model
# Attempting to fit SARIMAX(2, 2, 1, 12) Model
# Attempting to fit SARIMAX(2, 2, 2, 12) Model
# Attempting to fit SARIMAX(2, 2, 3, 12) Model
# Attempting to fit SARIMAX(2, 3, 0, 12) Model
# Attempting to fit SARIMAX(2, 3, 1, 12) Model
# Attempting to fit SARIMAX(2, 3, 2, 12) Model
# Attempting to fit SARIMAX(2, 3, 3, 12) Model
# Attempting to fit SARIMAX(3, 0, 0, 12) Model
# Attempting to fit SARIMAX(3, 0, 1, 12) Model
# Attempting to fit SARIMAX(3, 0, 2, 12) Model
# Attempting to fit SARIMAX(3, 0, 3, 12) Model
# Attempting to fit SARIMAX(3, 1, 0, 12) Model
# Attempting to fit SARIMAX(3, 1, 1, 12) Model
# Attempting to fit SARIMAX(3, 1, 2, 12) Model
# Attempting to fit SARIMAX(3, 1, 3, 12) Model
# Attempting to fit SARIMAX(3, 2, 0, 12) Model
# Attempting to fit SARIMAX(3, 2, 1, 12) Model
# Attempting to fit SARIMAX(3, 2, 2, 12) Model
# Attempting to fit SARIMAX(3, 2, 3, 12) Model
# Attempting to fit SARIMAX(3, 3, 0, 12) Model
# Attempting to fit SARIMAX(3, 3, 1, 12) Model
# Attempting to fit SARIMAX(3, 3, 2, 12) Model
# Attempting to fit SARIMAX(3, 3, 3, 12) Model
#
#
# MODEL FINISHED!
# Our model that minimizes AIC on the training data is the SARIMAX(0,0,0, 12).
# This model has an AIC of 10000000000000.

# %%
best_sarimax = SARIMAX(endog = train.dropna(),
                 order = (0, 1, 1),
                 seasonal_order = (0,0,0, 12))

model = best_sarimax.fit()
sarimax_pred = model.forecast(steps = len(test))

# %%
sarimax_pred
# Out:
# 236    129761.868823
# 237    129761.868823
# 238    129761.868823
# 239    129761.868823
# 240    129761.868823
#            ...
# 310    129761.868823
# 311    129761.868823
# 312    129761.868823
# 313    129761.868823
# 314    129761.868823
# Length: 79, dtype: float64

# %%
error = np.sqrt(mean_squared_error(test, sarima_pred))
print(f'RMSE: {round(error, 2)}')
# Out:
# RMSE: 3792.41

# %%
# Fit a SARIMA(0, 2, 1) x (0, 1, 2, 4) model.

sarima = SARIMAX(endog = train.astype(float).dropna(),
                 order = (0, 1, 1),              # (p, d, q)
                 seasonal_order = (0, 0, 0, 12)  # (P, D, Q, S)
                 ) 

# Fit SARIMA model.
model = sarima.fit()

# Generate predictions based on test set.
preds = model.predict(start=test.index[0], end = test.index[-1])

# Evaluate predictions.
print(np.sqrt(mean_squared_error(test, preds)))

# Plot data.
plt.figure(figsize=(10,6))
plt.plot(train, color = 'blue')
plt.plot(test, color = 'orange')
plt.plot(preds, color = 'green')
plt.title(label = 'Bus Ridership Monthly Volume with SARIMAX(0, 2, 1) x (0, 1, 2, 4) Predictions', fontsize=16)
plt.show();
# Out:
# 3792.4078761754563

# %% [markdown]
# Arima - Total turns
# SARIMAX - S = 12, grid search over the seasonal order

# %% [markdown]
# augment problem statement -> after x amount of turns, this is the time that another store can open

# %% [markdown]
# BAr
