# %% [markdown]
# # Starbucks and MTA Data

# %% [markdown]
# ## Problem Statement:
# Starbucks is a premier international coffee franchise with over 30,000 locations throughout the world. With New York City being one of the top cities to consume coffee, in all of the United States, Starbucks has imprinted its mark throughout the city, opening up more than 400 stores throughout the 5 boroughs, with 240 being specifically in Manhattan.
#
# The Metropolitan Transportation Authority (MTA) has become a very viable and popular means of transportation for people in New York City, seamlessly aiding people in getting to various part of the city that may be too far to walk or too expensive to take a taxi/uber to get too. With this means of transportation, thousands of people go through these arrays of turnstiles which leads to greater foot traffic in these general areas at certain times which would make it prime real estate to open up a Starbucks store.  On the other side of the coin, it will also tell us which stores maybe are losing foot traffic and will need to be looked into more to see if there has been a decrease in these stores profit and loss statements which may need to lead to relocation or shut down permanently. With looking at this turnstile data that the MTA provided, can we identify trends happening around certain subway stations that can possibly lead to expansion opportunities as well as mitigate risk with certain stores that aren’t becoming as popular
#
# We will assess our data with a time series analysis, using historical data of these stations and turnstiles to predict future foot traffic in each of the various locations. We will use the Seasonal Auto Regression Integrated Moving Average Exonginous (SARIMAX) model to evaluate and use regression, specifically Root Mean Squared Error (RMSE), to score our models.

# %% [markdown]
# ![](800px-MTA_New_York_City_Subway_logo.svg.png)
# ![](Starbucks_Corporation_Logo_2011.svg.png)

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# - [1.4 Acquiring and Preprocessing Data](#Acquiring-and-Preprocessing-Data)
# - [1.5 Data Dictionary](#Data-Dictionary)
# - [1.6 Loading Libraries](#Loading-Libraries)
# - [1.7 Loading Data](#Loading-Data)
# - [1.8 EDA](#EDA)
# - [1.9 Featured Engineering](#CFeatured-Engineering)
# - [1.10 Model Preparation](#Model-Preparation)
# - [1.11 Modeling](#Modeling)
# - [1.12 Model Selection](#Model-Selection)
# - [1.13 Model Evaluation](#Model-Evaluation)
# - [1.14 Conclusion](#Conclusion)
# - [1.15 Conclusion](#Conclusion)

# %% [markdown]
# ## Acquiring and Preprocessing Data

# %% [markdown]
# __Talk about other notebook__

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# |Feature|Type|Description|
# |---|---|---|
# |**State**|*object*|State|
# |**City**|*object*|City|
# |**Zip Codes**|*int*|Zip Code |
# |**Latitude**|*float*|Latitude |
# |**Longitude**|*float*|Longitude|
# |**ID**|*object*|Unique ID of each Data point|
# |**Name**|*object*|Store/Restaurant Name|
# |**Review Count**|*int*|Number of reviews
# |**Categories**|*object*|Category of each point|
# |**Rating**|*float*|Average rating of each point|
# |**Price**|*int*|Amount of $ signs of each point|
# |**High Value**|*float*|Average Adjusted Gross Income of people who made over 200,000 per Zip Code|
# |**AGI Sum**|*float*|Sum of the Total Average Income per threshold per Zip Code|
# |**Aff Perc**|*float*|Rate of Affluency per Zip Code (High Value /AGI Sum)|
# |**Count**|*int*|Count of Restaurants in particular Zip Code|

# %% [markdown]
# ## Loading Libraries

# %%
#cleaning libraries
import requests
import pandas as pd
import numpy as np
from PIL import Image
from difflib import get_close_matches 
#evaluation
import statsmodels.api as sm
from sklearn.pipeline import Pipeline,FeatureUnion
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans

#graphs
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Load the stations CSV we created in the Starbucks Cleaning notebook

# %%
stations = pd.read_csv('Data/stations.csv')
stations.head()
# Out:
#    Station_Latitude  Station_Longitude  Route_8  Route_9  Route_10  Route_11  \
# 0         40.740893         -74.001690      NaN      NaN       NaN       NaN
# 1         40.745906         -73.998041      NaN      NaN       NaN       NaN
# 2         40.747846         -73.946000      NaN      NaN       NaN       NaN
# 3         40.752287         -73.993391      NaN      NaN       NaN       NaN
# 4         40.757308         -73.989735      1.0      2.0       3.0       7.0
#
#    ADA  Free_Crossover   Latitude  Longitude         station  first_closest  \
# 0  1.0             1.0  40.740612 -74.001896         14th St       0.001861
# 1  0.0             1.0  40.745990 -73.997927         23rd St       0.003181
# 2  0.0             1.0  40.747807 -73.945829  23rd St-Ely Av       0.013156
# 3  1.0             1.0  40.752218 -64.744260         34th St       0.001281
# 4  1.0             1.0  40.757358 -73.989816         42nd St       0.000612
#
#              first_closest_store  second_closest second_closest_store  \
# 0  8th Ave just south of 14th St        0.002499           19th & 8th
# 1                     24th & 7th        0.003717           19th & 8th
# 2               Roosevelt Island        0.021601         69th & First
# 3          Penn Station by A,C,E        0.001281       One Penn Plaza
# 4                     42nd & 8th        0.000680    Union Square East
#
#    third_closest       third_closest_store
# 0       0.003523  Greenwich Ave at Bank St
# 1       0.003729                23rd & 1st
# 2       0.023777              75th & First
# 3       0.003779       32nd btwn 6th & 7th
# 4       0.001043                43rd & 8th

# %% [markdown]
# Load in the 2017 Turnstile data that we were able to obtain from the MTA website

# %%
df_2017 = pd.read_csv('Data/turnstile-usage-data-2017.csv')

# %%
df_2017.head()
# Out:
#     C/A  Unit       SCP Station Line Name Division                     Date  \
# 0  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 1  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 2  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 3  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
# 4  A002  R051  02-00-00   59 ST   NQR456W      BMT  2017-12-22T00:00:00.000
#
#        Time Description  Entries  \
# 0  23:00:00     REGULAR  6455787
# 1  19:00:00     REGULAR  6455505
# 2  15:00:00     REGULAR  6454819
# 3  11:00:00     REGULAR  6454437
# 4  07:00:00     REGULAR  6454285
#
#    Exits
# 0                                            2184977
# 1                                            2184926
# 2                                            2184867
# 3                                            2184773
# 4                                            2184501

# %% [markdown]
# ## Preliminary EDA

# %% [markdown]
# Within the Preliminary EDA, we will setup one Dataframe that will be used to start feature engineering and setting up various graphs to look at

# %%
df_2017.isnull().sum()
# Out:
# C/A                                                           0
# Unit                                                          0
# SCP                                                           0
# Station                                                       0
# Line Name                                                     0
# Division                                                      0
# Date                                                          0
# Time                                                          0
# Description                                                   0
# Entries                                                       0
# Exits                                                         0
# dtype: int64

# %%
len(df_2017['Line Name'])
# Out:
# 8880000

# %%
df_2017['Line Name'].unique()
# Out:
# array(['NQR456W', 'NQRW', 'ACENQRS1237W', 'BDFMNQRW', 'NRW', 'LNQR456W',
#        'JNQRZ6W', 'RNW', 'R1W', 'FJMZ', 'JZ', 'JZ456', 'ACJZ2345', 'BQ',
#        'S', 'S2345', 'BQS', 'Q', 'R2345', 'R', 'BDNQR', 'BDNQR2345',
#        'DFGMNR', 'DNR', 'N', 'ND', 'D', 'DFNQ', 'ACEL', 'FLM123', 'L',
#        'LG', 'LM', 'JMZ', 'JM', 'J', 'A', 'E', 'M', 'AC1', 'C', 'ABCD',
#        'BC', 'ACBD', 'ABCD1', 'ACENGRS1237W', 'ACE', 'CE', 'ABCDEFM',
#        'ACE23', '2345ACJZ', 'AC', 'ACF', 'ACG', 'ACS', 'ACJLZ', 'AS',
#        'BD', 'BD4', 'BDE', 'EM', 'EM6', 'EMG', 'EMR', 'MR', 'EFMR7',
#        'EFMR', 'EF', 'F', 'G', 'GL', 'BDFM', 'BDFM7', 'FM', 'BDFQ6', 'FG',
#        '1', 1, '1RW', '23', '123', '123FLM', 123, '1237ACENQRSW', '1ABCD',
#        45], dtype=object)

# %%
df_2017 = df_2017[(df_2017['Line Name']!= 1) & (df_2017['Line Name']!= 123) & (df_2017['Line Name']!= 45)]

# %%
df_e = df_2017.loc[df_2017['Line Name'].str.contains('E'),:]

# %%
df_e.head()
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#                            Date      Time Description  Entries  \
# 118432  2017-12-22T00:00:00.000  23:00:00     REGULAR  7357995
# 118433  2017-12-22T00:00:00.000  19:00:00     REGULAR  7357446
# 118434  2017-12-22T00:00:00.000  15:00:00     REGULAR  7356450
# 118435  2017-12-22T00:00:00.000  11:00:00     REGULAR  7355728
# 118436  2017-12-22T00:00:00.000  07:00:00     REGULAR  7355235
#
#         Exits
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730

# %%
len(df_e)
# Out:
# 884882

# %%
del(df_2017)

# %%
def date_manip(df):
    new_date = [i.split('T')[0] for i in df['Date']]
    df['Date'] = new_date
    df['date_time'] = pd.to_datetime(df.Date + ' ' + df.Time)
    return df.head()

# %%
date_manip(df_e)
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               Date      Time Description  Entries  \
# 118432  2017-12-22  23:00:00     REGULAR  7357995
# 118433  2017-12-22  19:00:00     REGULAR  7357446
# 118434  2017-12-22  15:00:00     REGULAR  7356450
# 118435  2017-12-22  11:00:00     REGULAR  7355728
# 118436  2017-12-22  07:00:00     REGULAR  7355235
#
#         Exits                                                       \
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730
#
#                  date_time
# 118432 2017-12-22 23:00:00
# 118433 2017-12-22 19:00:00
# 118434 2017-12-22 15:00:00
# 118435 2017-12-22 11:00:00
# 118436 2017-12-22 07:00:00

# %%
def doy(day):
    return day.day_name()

# %%
def moy(month):
    return month.month_name()

# %%
def map_day_to_df(df):
    df['day'] = df['date_time'].map(doy)
    return df.head()

# %%
def map_month_to_df(df):
    df['month'] = df['date_time'].map(moy)
    return df.head()

# %%
map_day_to_df(df_e)
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               Date      Time Description  Entries  \
# 118432  2017-12-22  23:00:00     REGULAR  7357995
# 118433  2017-12-22  19:00:00     REGULAR  7357446
# 118434  2017-12-22  15:00:00     REGULAR  7356450
# 118435  2017-12-22  11:00:00     REGULAR  7355728
# 118436  2017-12-22  07:00:00     REGULAR  7355235
#
#         Exits                                                       \
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730
#
#                  date_time     day
# 118432 2017-12-22 23:00:00  Friday
# 118433 2017-12-22 19:00:00  Friday
# 118434 2017-12-22 15:00:00  Friday
# 118435 2017-12-22 11:00:00  Friday
# 118436 2017-12-22 07:00:00  Friday

# %%
map_month_to_df(df_e)
# Out:
#          C/A  Unit       SCP         Station     Line Name Division  \
# 118432  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118433  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118434  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118435  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 118436  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               Date      Time Description  Entries  \
# 118432  2017-12-22  23:00:00     REGULAR  7357995
# 118433  2017-12-22  19:00:00     REGULAR  7357446
# 118434  2017-12-22  15:00:00     REGULAR  7356450
# 118435  2017-12-22  11:00:00     REGULAR  7355728
# 118436  2017-12-22  07:00:00     REGULAR  7355235
#
#         Exits                                                       \
# 118432                                            8791810
# 118433                                            8791371
# 118434                                            8790311
# 118435                                            8789251
# 118436                                            8787730
#
#                  date_time     day     month
# 118432 2017-12-22 23:00:00  Friday  December
# 118433 2017-12-22 19:00:00  Friday  December
# 118434 2017-12-22 15:00:00  Friday  December
# 118435 2017-12-22 11:00:00  Friday  December
# 118436 2017-12-22 07:00:00  Friday  December

# %%
stations['station'] = stations['station'].str.upper()

# %%
stations.head()
# Out:
#    Station_Latitude  Station_Longitude  Route_8  Route_9  Route_10  Route_11  \
# 0         40.740893         -74.001690      NaN      NaN       NaN       NaN
# 1         40.745906         -73.998041      NaN      NaN       NaN       NaN
# 2         40.747846         -73.946000      NaN      NaN       NaN       NaN
# 3         40.752287         -73.993391      NaN      NaN       NaN       NaN
# 4         40.757308         -73.989735      1.0      2.0       3.0       7.0
#
#    ADA  Free_Crossover   Latitude  Longitude         station  first_closest  \
# 0  1.0             1.0  40.740612 -74.001896         14TH ST       0.001861
# 1  0.0             1.0  40.745990 -73.997927         23RD ST       0.003181
# 2  0.0             1.0  40.747807 -73.945829  23RD ST-ELY AV       0.013156
# 3  1.0             1.0  40.752218 -64.744260         34TH ST       0.001281
# 4  1.0             1.0  40.757358 -73.989816         42ND ST       0.000612
#
#              first_closest_store  second_closest second_closest_store  \
# 0  8th Ave just south of 14th St        0.002499           19th & 8th
# 1                     24th & 7th        0.003717           19th & 8th
# 2               Roosevelt Island        0.021601         69th & First
# 3          Penn Station by A,C,E        0.001281       One Penn Plaza
# 4                     42nd & 8th        0.000680    Union Square East
#
#    third_closest       third_closest_store
# 0       0.003523  Greenwich Ave at Bank St
# 1       0.003729                23rd & 1st
# 2       0.023777              75th & First
# 3       0.003779       32nd btwn 6th & 7th
# 4       0.001043                43rd & 8th

# %% [markdown]
# The next step we had to take was to find a way to merge now our two station data sets together, one with the station locations and closest starbucks and the other with the turnstile info. For that, we needed to get teh station names to match up together. We had to make a conversion dictionary that would then be mapped to our station location dataframe as a means of merging them together. With the help of the get_close_matches fucntion. this expediated the process for us to search within the unique values of the turnstile dataframe to match the closest named station which did work at about a 75% clip. The other 25% where it wasnt able to indentify, we had to mannually go through the list to figure out the matching station.

# %%
from difflib import SequenceMatcher,get_close_matches

SequenceMatcher(None,'Prospect Park' , 'PROSPECT PARK').ratio()
# Out:
# 0.23076923076923078

# %%
stations['station'].sort_values().unique()
# Out:
# array(['14TH ST', '23RD ST', '23RD ST-ELY AV', '34TH ST', '42ND ST',
#        '45 RD-COURT HOUSE SQ', '50TH ST', '51ST ST', '5TH AV-53RD ST',
#        '75TH AV', '7TH AV', '8TH AV', 'BROADWAY-74TH ST', 'CANAL ST',
#        'CHAMBERS ST', 'FOREST HILLS-71ST AV',
#        'JACKSON HEIGHTS-ROOSEVELT AVE', 'JAMAICA-VAN WYCK',
#        'KEW GARDENS-UNION TURNPIKE', 'LEXINGTON AV-53RD ST', 'PARK PLACE',
#        'PARSONS BLVD-ARCHER AV - JAMAICA CENTER', 'QUEENS PLAZA',
#        'SPRING ST', 'SUTPHIN BLVD-ARCHER AV - JFK', 'TIMES SQUARE',
#        'TIMES SQUARE-42ND ST', 'WORLD TRADE CENTER'], dtype=object)

# %%
df_e['Station'].unique()
# Out:
# array(['TIMES SQ-42 ST', '8 AV', 'JFK JAMAICA CT1', '42 ST-PORT AUTH',
#        '34 ST-PENN STA', '23 ST', '14 ST', 'W 4 ST-WASH SQ', 'SPRING ST',
#        'CANAL ST', 'CHAMBERS ST', 'WORLD TRADE CTR', '7 AV', '5 AV/53 ST',
#        'LEXINGTON AV/53', 'COURT SQ-23 ST', 'QUEENS PLAZA',
#        'JKSN HT-ROOSVLT', 'FOREST HILLS 71', '75 AV', 'KEW GARDENS',
#        'BRIARWOOD', 'COURT SQ'], dtype=object)

# %%
get_close_matches('TIMES SQUARE-42ND ST' ,stations['station'].unique(), n=5)
# Out:
# ['TIMES SQUARE-42ND ST', 'TIMES SQUARE']

# %% [markdown]
# This above is an example of how the get_close_matches function worked. This was run with all the unique values we had in the df_e dataframe to match the values in the df dataframe.

# %%
conv_station_dict = {
    'TIMES SQUARE-42ND ST': 'TIMES SQ-42 ST', 
    '8TH AV': '8 AV', 
    'SUTPHIN BLVD-ARCHER AV - JFK':'JFK JAMAICA CT1', 
    '42ND ST': '42 ST-PORT AUTH',
    '34TH ST': '34 ST-PENN STA', 
    '23RD ST':'23 ST', 
    '14TH ST':'14 ST', 
    'WEST 4TH ST': 'W 4 ST-WASH SQ', 
    'SPRING ST': 'SPRING ST',
    'CANAL ST': 'CANAL ST', 
    'CHAMBERS ST': 'CHAMBERS ST', 
    'WORLD TRADE CENTER': 'WORLD TRADE CTR', 
    '7TH AV': '7 AV', 
    '5TH AV-53RD ST': '5 AV/53 ST',
    'LEXINGTON AV-53RD ST': 'LEXINGTON AV/53', 
    'COURT ST': 'COURT SQ-23 ST', 
    'QUEENS PLAZA': 'QUEENS PLAZA',
    'JACKSON HEIGHTS-ROOSEVELT AVE': 'JKSN HT-ROOSVLT', 
    'FOREST HILLS-71ST AV': 'FOREST HILLS 71', 
    '75TH AV': '75 AV', 
    'KEW GARDENS-UNION TURNPIKE':'KEW GARDENS',
    'JAMAICA-VAN WYCK': 'BRIARWOOD', 
}

stations['station'] = stations['station'].map(conv_station_dict)

# %%
stations['station'].unique()
# Out:
# array(['14 ST', '23 ST', nan, '34 ST-PENN STA', '42 ST-PORT AUTH',
#        '5 AV/53 ST', '75 AV', '7 AV', '8 AV', 'CANAL ST', 'CHAMBERS ST',
#        'FOREST HILLS 71', 'JKSN HT-ROOSVLT', 'BRIARWOOD', 'KEW GARDENS',
#        'LEXINGTON AV/53', 'QUEENS PLAZA', 'SPRING ST', 'JFK JAMAICA CT1',
#        'TIMES SQ-42 ST', 'WORLD TRADE CTR'], dtype=object)

# %%
temp_stations = stations.dropna(axis=0, subset=['station'])

# %%
temp_stations.head()
# Out:
#    Station_Latitude  Station_Longitude  Route_8  Route_9  Route_10  Route_11  \
# 0         40.740893         -74.001690      NaN      NaN       NaN       NaN
# 1         40.745906         -73.998041      NaN      NaN       NaN       NaN
# 3         40.752287         -73.993391      NaN      NaN       NaN       NaN
# 4         40.757308         -73.989735      1.0      2.0       3.0       7.0
# 8         40.760167         -73.975224      NaN      NaN       NaN       NaN
#
#    ADA  Free_Crossover   Latitude  Longitude          station  first_closest  \
# 0  1.0             1.0  40.740612 -74.001896            14 ST       0.001861
# 1  0.0             1.0  40.745990 -73.997927            23 ST       0.003181
# 3  1.0             1.0  40.752218 -64.744260   34 ST-PENN STA       0.001281
# 4  1.0             1.0  40.757358 -73.989816  42 ST-PORT AUTH       0.000612
# 8  0.0             1.0  40.760068 -73.975054       5 AV/53 ST       0.001516
#
#              first_closest_store  second_closest   second_closest_store  \
# 0  8th Ave just south of 14th St        0.002499             19th & 8th
# 1                     24th & 7th        0.003717             19th & 8th
# 3          Penn Station by A,C,E        0.001281         One Penn Plaza
# 4                     42nd & 8th        0.000680      Union Square East
# 8                 53rd & Madison        0.001719  UNIQLO @ 53rd & Fifth
#
#    third_closest         third_closest_store
# 0       0.003523    Greenwich Ave at Bank St
# 1       0.003729                  23rd & 1st
# 3       0.003779         32nd btwn 6th & 7th
# 4       0.001043                  43rd & 8th
# 8       0.001915  53rd Inside Park Ave Plaza

# %%
temp_stations = temp_stations[['station', 'Station_Latitude', 'Station_Longitude', 'first_closest', 'first_closest_store', 'second_closest', 'second_closest_store', 'third_closest', 'third_closest_store']]

# %%
temp_stations.rename(columns = {'station': 'Station'}, inplace = True)

# %%
temp_stations[temp_stations['Station'] == '34 ST-PENN STA']
# Out:
#           Station  Station_Latitude  Station_Longitude  first_closest  \
# 3  34 ST-PENN STA         40.752287         -73.993391       0.001281
#
#      first_closest_store  second_closest second_closest_store  third_closest  \
# 3  Penn Station by A,C,E        0.001281       One Penn Plaza       0.003779
#
#    third_closest_store
# 3  32nd btwn 6th & 7th

# %%
df_merged =  pd.merge(left = df_e,
        right = temp_stations,
        how ='inner',
        on = 'Station')

# %%
df_merged.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries',
#        'Exits                                                     ',
#        'date_time', 'day', 'month', 'Station_Latitude', 'Station_Longitude',
#        'first_closest', 'first_closest_store', 'second_closest',
#        'second_closest_store', 'third_closest', 'third_closest_store'],
#       dtype='object')

# %%
df_merged.rename(columns = {'Exits                                                     ': 'Exits'}, inplace = True)

# %%
df_merged = df_merged.set_index(['date_time'])

# %%
df_merged.sort_index(inplace = True, ascending = False)

# %%
df_merged.head()
# Out:
#                       C/A  Unit       SCP         Station     Line Name  \
# date_time
# 2017-12-22 23:00:00  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W
# 2017-12-22 23:00:00  N091  R029  02-05-03     CHAMBERS ST         ACE23
# 2017-12-22 23:00:00  N091  R029  02-06-00     CHAMBERS ST         ACE23
# 2017-12-22 23:00:00  N091  R029  02-06-01     CHAMBERS ST         ACE23
# 2017-12-22 23:00:00  N092  R029  03-00-00     CHAMBERS ST         ACE23
#
#                     Division        Date      Time Description   Entries  ...  \
# date_time                                                                 ...
# 2017-12-22 23:00:00      BMT  2017-12-22  23:00:00     REGULAR   7357995  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR  67874755  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR   4106806  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR   6941835  ...
# 2017-12-22 23:00:00      IND  2017-12-22  23:00:00     REGULAR   4868208  ...
#
#                         day     month Station_Latitude  Station_Longitude  \
# date_time
# 2017-12-22 23:00:00  Friday  December        40.754672         -73.986754
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
# 2017-12-22 23:00:00  Friday  December        40.714111         -74.008585
#
#                      first_closest     first_closest_store second_closest  \
# date_time
# 2017-12-22 23:00:00       0.001214     42nd btwn 3rd & Lex       0.001846
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
# 2017-12-22 23:00:00       0.000759  Church Street & Murray       0.001266
#
#                            second_closest_store third_closest  \
# date_time
# 2017-12-22 23:00:00                  39th & 7th      0.002298
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
# 2017-12-22 23:00:00  Chambers and West Broadway      0.001697
#
#                            third_closest_store
# date_time
# 2017-12-22 23:00:00  Broadway Btwn 37th & 38th
# 2017-12-22 23:00:00    Broadway at Barclay Str
# 2017-12-22 23:00:00    Broadway at Barclay Str
# 2017-12-22 23:00:00    Broadway at Barclay Str
# 2017-12-22 23:00:00    Broadway at Barclay Str
#
# [5 rows x 21 columns]

# %% [markdown]
# For some locations, Starbucks is open 24 hours a day. However, normal operations for Starbucks during the week are between 07:00 AM – 11:00 PM. Since most of Starbucks business comes in during the morning time as their primary source of business is coffee, we will filter out the hours to 06:00 AM - 12:00PM.

# %%
df_merged.between_time('06:00:00', '12:00:00')
# Out:
#                        C/A  Unit       SCP          Station     Line Name  \
# date_time
# 2017-12-22 12:00:00   N078  R175  01-00-00            14 ST          ACEL
# 2017-12-22 12:00:00  N309A  R140  00-03-01     QUEENS PLAZA           EMR
# 2017-12-22 12:00:00   N078  R175  01-00-01            14 ST          ACEL
# 2017-12-22 12:00:00  N309A  R140  00-03-02     QUEENS PLAZA           EMR
# 2017-12-22 12:00:00  N309A  R140  00-06-03     QUEENS PLAZA           EMR
# ...                    ...   ...       ...              ...           ...
# 2016-12-31 07:00:00   N063  R011  02-00-04  42 ST-PORT AUTH  ACENQRS1237W
# 2016-12-31 07:00:00   N094  R029  01-00-02  WORLD TRADE CTR         ACE23
# 2016-12-31 07:00:00   A021  R032  01-00-05   TIMES SQ-42 ST  ACENQRS1237W
# 2016-12-31 07:00:00   N077  R111  02-06-02            23 ST            CE
# 2016-12-31 07:00:00   N067  R012  00-05-01   34 ST-PENN STA           ACE
#
#                     Division        Date      Time Description  Entries  ...  \
# date_time                                                                ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR  5519852  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR   109917  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR   557480  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR   449767  ...
# 2017-12-22 12:00:00      IND  2017-12-22  12:00:00     REGULAR     3678  ...
# ...                      ...         ...       ...         ...      ...  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR  8019665  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR  4708852  ...
# 2016-12-31 07:00:00      BMT  2016-12-31  07:00:00     REGULAR   966104  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR  4123412  ...
# 2016-12-31 07:00:00      IND  2016-12-31  07:00:00     REGULAR  4522762  ...
#
#                           day     month Station_Latitude  Station_Longitude  \
# date_time
# 2017-12-22 12:00:00    Friday  December        40.740893         -74.001690
# 2017-12-22 12:00:00    Friday  December        40.748973         -73.937243
# 2017-12-22 12:00:00    Friday  December        40.740893         -74.001690
# 2017-12-22 12:00:00    Friday  December        40.748973         -73.937243
# 2017-12-22 12:00:00    Friday  December        40.748973         -73.937243
# ...                       ...       ...              ...                ...
# 2016-12-31 07:00:00  Saturday  December        40.757308         -73.989735
# 2016-12-31 07:00:00  Saturday  December        40.712582         -74.009781
# 2016-12-31 07:00:00  Saturday  December        40.754672         -73.986754
# 2016-12-31 07:00:00  Saturday  December        40.745906         -73.998041
# 2016-12-31 07:00:00  Saturday  December        40.752287         -73.993391
#
#                      first_closest            first_closest_store  \
# date_time
# 2017-12-22 12:00:00       0.001861  8th Ave just south of 14th St
# 2017-12-22 12:00:00       0.015421           35th Ave and 37th St
# 2017-12-22 12:00:00       0.001861  8th Ave just south of 14th St
# 2017-12-22 12:00:00       0.015421           35th Ave and 37th St
# 2017-12-22 12:00:00       0.015421           35th Ave and 37th St
# ...                            ...                            ...
# 2016-12-31 07:00:00       0.000612                     42nd & 8th
# 2016-12-31 07:00:00       0.001262         Church Street & Murray
# 2016-12-31 07:00:00       0.001214            42nd btwn 3rd & Lex
# 2016-12-31 07:00:00       0.003181                     24th & 7th
# 2016-12-31 07:00:00       0.001281          Penn Station by A,C,E
#
#                     second_closest     second_closest_store third_closest  \
# date_time
# 2017-12-22 12:00:00       0.002499               19th & 8th      0.003523
# 2017-12-22 12:00:00       0.017912           31-01 Broadway      0.018468
# 2017-12-22 12:00:00       0.002499               19th & 8th      0.003523
# 2017-12-22 12:00:00       0.017912           31-01 Broadway      0.018468
# 2017-12-22 12:00:00       0.017912           31-01 Broadway      0.018468
# ...                            ...                      ...           ...
# 2016-12-31 07:00:00       0.000680        Union Square East      0.001043
# 2016-12-31 07:00:00       0.001434  Broadway at Barclay Str      0.002896
# 2016-12-31 07:00:00       0.001846               39th & 7th      0.002298
# 2016-12-31 07:00:00       0.003717               19th & 8th      0.003729
# 2016-12-31 07:00:00       0.001281           One Penn Plaza      0.003779
#
#                            third_closest_store
# date_time
# 2017-12-22 12:00:00   Greenwich Ave at Bank St
# 2017-12-22 12:00:00           Roosevelt Island
# 2017-12-22 12:00:00   Greenwich Ave at Bank St
# 2017-12-22 12:00:00           Roosevelt Island
# 2017-12-22 12:00:00           Roosevelt Island
# ...                                        ...
# 2016-12-31 07:00:00                 43rd & 8th
# 2016-12-31 07:00:00            Nassau & Fulton
# 2016-12-31 07:00:00  Broadway Btwn 37th & 38th
# 2016-12-31 07:00:00                 23rd & 1st
# 2016-12-31 07:00:00        32nd btwn 6th & 7th
#
# [256578 rows x 21 columns]

# %%
df_merged.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries', 'Exits', 'day', 'month',
#        'Station_Latitude', 'Station_Longitude', 'first_closest',
#        'first_closest_store', 'second_closest', 'second_closest_store',
#        'third_closest', 'third_closest_store'],
#       dtype='object')

# %%
df_merged.columns
# Out:
# Index(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division', 'Date',
#        'Time', 'Description', 'Entries', 'Exits', 'day', 'month',
#        'Station_Latitude', 'Station_Longitude', 'first_closest',
#        'first_closest_store', 'second_closest', 'second_closest_store',
#        'third_closest', 'third_closest_store'],
#       dtype='object')

# %%
df= (df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station','Line Name', 'Division', 'Date','month', 'day', 'Station_Latitude', 'Station_Longitude', 'first_closest',
                   'first_closest_store','second_closest', 'second_closest_store','third_closest',
                   'third_closest_store'])['Entries'].max() 
 - df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station','Line Name', 'Division','Date','month', 'day', 'Station_Latitude', 'Station_Longitude','first_closest',
                     'first_closest_store','second_closest', 'second_closest_store','third_closest',
                     'third_closest_store'])['Entries'].min()).reset_index()

# %%
exits = (df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station', 'Line Name', 'Division','Date','month', 'day', 'first_closest',
                   'first_closest_store','second_closest', 'second_closest_store','third_closest',
                   'third_closest_store'])['Exits'].max() 
 - df_merged.groupby(['C/A', 'Unit', 'SCP', 'Station','Line Name', 'Division','Date','month', 'day','first_closest',
                     'first_closest_store','second_closest', 'second_closest_store','third_closest',
                     'third_closest_store'])['Exits'].min()).reset_index()

# %%
exits.head()
# Out:
#     C/A  Unit       SCP         Station     Line Name Division        Date  \
# 0  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2016-12-31
# 1  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-01
# 2  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-02
# 3  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-03
# 4  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-04
#
#       month        day  first_closest  first_closest_store  second_closest  \
# 0  December   Saturday       0.001214  42nd btwn 3rd & Lex        0.001846
# 1   January     Sunday       0.001214  42nd btwn 3rd & Lex        0.001846
# 2   January     Monday       0.001214  42nd btwn 3rd & Lex        0.001846
# 3   January    Tuesday       0.001214  42nd btwn 3rd & Lex        0.001846
# 4   January  Wednesday       0.001214  42nd btwn 3rd & Lex        0.001846
#
#   second_closest_store  third_closest        third_closest_store  Exits
# 0           39th & 7th       0.002298  Broadway Btwn 37th & 38th   1607
# 1           39th & 7th       0.002298  Broadway Btwn 37th & 38th   1568
# 2           39th & 7th       0.002298  Broadway Btwn 37th & 38th   1808
# 3           39th & 7th       0.002298  Broadway Btwn 37th & 38th   3895
# 4           39th & 7th       0.002298  Broadway Btwn 37th & 38th   4108

# %%
df['Exits'] = exits['Exits']

# %%
df.head()
# Out:
#     C/A  Unit       SCP         Station     Line Name Division        Date  \
# 0  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2016-12-31
# 1  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-01
# 2  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-02
# 3  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-03
# 4  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT  2017-01-04
#
#       month        day  Station_Latitude  Station_Longitude  first_closest  \
# 0  December   Saturday         40.754672         -73.986754       0.001214
# 1   January     Sunday         40.754672         -73.986754       0.001214
# 2   January     Monday         40.754672         -73.986754       0.001214
# 3   January    Tuesday         40.754672         -73.986754       0.001214
# 4   January  Wednesday         40.754672         -73.986754       0.001214
#
#    first_closest_store  second_closest second_closest_store  third_closest  \
# 0  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 1  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 2  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 3  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
# 4  42nd btwn 3rd & Lex        0.001846           39th & 7th       0.002298
#
#          third_closest_store  Entries  Exits
# 0  Broadway Btwn 37th & 38th      622   1607
# 1  Broadway Btwn 37th & 38th      767   1568
# 2  Broadway Btwn 37th & 38th     1192   1808
# 3  Broadway Btwn 37th & 38th     3193   3895
# 4  Broadway Btwn 37th & 38th     3124   4108

# %%
df.dtypes
# Out:
# C/A                      object
# Unit                     object
# SCP                      object
# Station                  object
# Line Name                object
# Division                 object
# Date                     object
# month                    object
# day                      object
# Station_Latitude        float64
# Station_Longitude       float64
# first_closest           float64
# first_closest_store      object
# second_closest          float64
# second_closest_store     object
# third_closest           float64
# third_closest_store      object
# Entries                   int64
# Exits                     int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# C/A                      object
# Unit                     object
# SCP                      object
# Station                  object
# Line Name                object
# Division                 object
# month                    object
# day                      object
# Station_Latitude        float64
# Station_Longitude       float64
# first_closest           float64
# first_closest_store      object
# second_closest          float64
# second_closest_store     object
# third_closest           float64
# third_closest_store      object
# Entries                   int64
# Exits                     int64
# dtype: object

# %%
df = df.set_index(['Date'])

# %%
df['Entries'].sort_values().tail(20)
# Out:
# Date
# 2017-10-16       4997757
# 2017-12-01       5338284
# 2017-12-19       5379758
# 2017-06-22       5449929
# 2017-12-01       8224299
# 2017-07-04       8266473
# 2017-11-30      11007391
# 2017-03-02      14180769
# 2017-07-23      16594428
# 2017-03-06      36107735
# 2017-03-07      36110538
# 2017-01-08      50330602
# 2017-01-03      66562129
# 2017-03-07      99848623
# 2017-01-09     117440381
# 2017-06-17     150102672
# 2017-08-27     735329800
# 2017-01-26    1153072639
# 2017-08-09    1211446878
# 2017-12-19    1579485694
# Name: Entries, dtype: int64

# %%
df = df[(df['Entries'] < 30000) & (df['Entries'] < 30000) ]

# %%
df['Entries'].sort_values().tail(20)
# Out:
# Date
# 2017-05-01     5925
# 2017-07-15     5963
# 2017-07-09     6095
# 2017-07-16     6560
# 2017-07-08     6644
# 2017-07-16     6748
# 2017-07-09     7264
# 2017-07-15     7294
# 2017-07-15     7591
# 2017-07-08     7609
# 2017-07-15     7641
# 2017-07-08     8440
# 2017-10-15    13783
# 2017-06-15    17058
# 2017-12-19    18945
# 2017-09-19    22133
# 2017-08-26    23347
# 2017-10-22    29355
# 2017-04-12    29581
# 2017-09-30    29697
# Name: Entries, dtype: int64

# %%
df['Exits'].sort_values().tail(20)
# Out:
# Date
# 2017-02-28     9783
# 2017-10-15     9800
# 2017-12-14     9833
# 2017-03-03     9833
# 2017-02-03     9842
# 2017-04-25     9849
# 2017-02-17     9875
# 2017-03-02     9904
# 2017-02-13    10003
# 2017-08-07    10027
# 2017-11-10    10104
# 2017-12-15    10191
# 2017-02-16    10204
# 2017-11-07    10954
# 2017-09-19    11514
# 2017-10-22    15716
# 2017-06-15    22306
# 2017-08-26    32009
# 2017-04-12    34678
# 2017-09-30    38249
# Name: Exits, dtype: int64

# %%
df = df[(df['Exits'] < 30000) & (df['Exits'] < 30000) ]

# %%
df['Exits'].sort_values().tail(20)
# Out:
# Date
# 2017-02-14     9690
# 2017-11-30     9709
# 2017-11-17     9716
# 2017-02-28     9783
# 2017-10-15     9800
# 2017-03-03     9833
# 2017-12-14     9833
# 2017-02-03     9842
# 2017-04-25     9849
# 2017-02-17     9875
# 2017-03-02     9904
# 2017-02-13    10003
# 2017-08-07    10027
# 2017-11-10    10104
# 2017-12-15    10191
# 2017-02-16    10204
# 2017-11-07    10954
# 2017-09-19    11514
# 2017-10-22    15716
# 2017-06-15    22306
# Name: Exits, dtype: int64

# %%
df.head()
# Out:
#              C/A  Unit       SCP         Station     Line Name Division  \
# Date
# 2016-12-31  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-01  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-02  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-03  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2017-01-04  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#                month        day  Station_Latitude  Station_Longitude  \
# Date
# 2016-12-31  December   Saturday         40.754672         -73.986754
# 2017-01-01   January     Sunday         40.754672         -73.986754
# 2017-01-02   January     Monday         40.754672         -73.986754
# 2017-01-03   January    Tuesday         40.754672         -73.986754
# 2017-01-04   January  Wednesday         40.754672         -73.986754
#
#             first_closest  first_closest_store  second_closest  \
# Date
# 2016-12-31       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-01       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-02       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-03       0.001214  42nd btwn 3rd & Lex        0.001846
# 2017-01-04       0.001214  42nd btwn 3rd & Lex        0.001846
#
#            second_closest_store  third_closest        third_closest_store  \
# Date
# 2016-12-31           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-01           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-02           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-03           39th & 7th       0.002298  Broadway Btwn 37th & 38th
# 2017-01-04           39th & 7th       0.002298  Broadway Btwn 37th & 38th
#
#             Entries  Exits
# Date
# 2016-12-31      622   1607
# 2017-01-01      767   1568
# 2017-01-02     1192   1808
# 2017-01-03     3193   3895
# 2017-01-04     3124   4108

# %%
df.describe()
# Out:
#        Station_Latitude  Station_Longitude  first_closest  second_closest  \
# count     107308.000000      107308.000000  107308.000000   107308.000000
# mean          40.741437         -73.956242       0.003586        0.005845
# std            0.018967           0.061567       0.006729        0.008725
# min           40.700486         -74.009781       0.000381        0.000680
# 25%           40.721691         -73.993391       0.000612        0.001281
# 50%           40.748973         -73.986754       0.001262        0.001827
# 75%           40.757308         -73.937243       0.001516        0.003717
# max           40.762862         -73.807969       0.030072        0.033464
#
#        third_closest        Entries          Exits
# count  107308.000000  107308.000000  107308.000000
# mean        0.007382    1104.571803     896.392841
# std         0.009408     983.268015    1036.479659
# min         0.001043       0.000000       0.000000
# 25%         0.001915     334.750000     177.000000
# 50%         0.003136     899.000000     579.000000
# 75%         0.009394    1632.000000    1183.000000
# max         0.035837   29355.000000   22306.000000

# %% [markdown]
# ## Featured Engineering

# %%
df['total_turns'] = df['Entries'] + df['Exits']

# %%
df['avg_distance'] = df['first_closest'] * df['second_closest'] * df['third_closest']

# %% [markdown]
# ## Graph EDA

# %%
station_names = df['Station'].sort_values().unique()

# %%
temp = df.groupby(['Station','Date'])['total_turns'].sum().reset_index().set_index('Date')

# %%
plt.figure(figsize=(20, 8))
sns.lineplot(x =temp.index, y = temp.total_turns, hue = temp.Station)

# %%
df.groupby(['Station'])['total_turns'].sum()
# Out:
# Station
# 14 ST               1274359
# 23 ST               9606263
# 34 ST-PENN STA     28065818
# 42 ST-PORT AUTH    41218502
# 5 AV/53 ST         12704970
# 7 AV                8627006
# 75 AV                956893
# 8 AV                4403135
# BRIARWOOD           1246637
# CANAL ST            4853647
# CHAMBERS ST        11707085
# FOREST HILLS 71    10593588
# JFK JAMAICA CT1     4396584
# JKSN HT-ROOSVLT    12200934
# KEW GARDENS         9528862
# LEXINGTON AV/53    20514569
# QUEENS PLAZA        5192568
# SPRING ST           2669806
# TIMES SQ-42 ST     18475624
# WORLD TRADE CTR     6364582
# Name: total_turns, dtype: int64

# %%
# Have two sets of data we want to plot
bars1 = df.groupby(['Station'])['total_turns'].sum()
bars2 = df.groupby(['Station'])['avg_distance'].mean()

# arange x values to be plotted
b1 = np.arange(len(bars1))
b2 = [x + barWidth for x in b1]
b3 = r1+r2 

#Set up Graph
fig = plt.figure(figsize = (15,8))
ax = plt.subplot(111)
barWidth = 0.3

# Create Total Turns bar
ax.bar(b1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', capsize=7, label='Turns (in Millions)')
plt.xticks([r + barWidth for r in range(len(b3))], station_names, rotation=45,fontsize = 15)
plt.setp(ax.xaxis.get_majorticklabels(), ha='right')
plt.yticks(fontsize = 10)
plt.ylabel('Total Turns', fontsize = 20)
# Create Starbucks Distance
ax2 = ax.twinx()
ax2.bar(b2, bars2, width = barWidth, color = 'green', edgecolor = 'black', capsize=7, label='Starbucks Distance')
plt.ylabel('Distance', fontsize = 20)

plt.title("Total Turns and Distance",  fontsize= 25)
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0, fontsize = 15)

plt.show()

# %%
plt.figure(figsize=(10, 8))

df.groupby(['Station'])['total_turns'].sum().sort_values().plot(kind = 'barh', colors = 'green', edgecolor='black',
                                                               linewidth='3')
plt.title('Total Entries per Month(In Tens of Millions)',fontsize = 20)
plt.xlabel('Total Turns', fontsize = 15)
plt.ylabel('Month',fontsize = 15)
# Out:
# Text(0, 0.5, 'Month')

# %%
temp = [df[df['Station'] == i] for i in df['Station'].unique()]

# %% [markdown]
# ### Port Authority

# %%
penn = df_cleaned[df['Station'] == '34 ST-PENN STA']

# %%
penn1 = df.loc[df['Station'] == '34 ST-PENN STA',:].groupby('Date').sum()

# %%
plt.figure(figsize=(24,10))
penn1['Entries'].plot()

# %%
plot_series(penn1.resample('MS', ## YS is year start rather then y which is Year end
                        closed = 'left').mean(),
            ['Entries'],
            title = 'Average Entries',
            steps = 1)

# %%
plt.figure(figsize=(24,10))
penn['Entries'].plot()

# %%
plt.figure(figsize=(10, 8))
penn.groupby('day')['Entries'].sum().sort_values().plot(kind = 'barh', colors = 'green', edgecolor='black',
                                                               linewidth='3')
plt.title('Penn Station Entries by Day of Week', fontsize = 20)
plt.xlabel('Total Entries', fontsize = 15)
plt.ylabel('Day of Week', fontsize = 15)
# Out:
# Text(0, 0.5, 'Day of Week')

# %%
penn['week_entries'] = penn['Entries'].rolling(7).mean()
penn['month_entries'] = penn['Entries'].rolling(30).mean()
penn['quarter_entries'] = penn['Entries'].rolling(91).mean()

# %%
penn[['week_entries', 'month_entries', 'quarter_entries']]
# Out:
#             week_entries  month_entries  quarter_entries
# Date
# 2016-12-31           NaN            NaN              NaN
# 2017-01-01           NaN            NaN              NaN
# 2017-01-02           NaN            NaN              NaN
# 2017-01-03           NaN            NaN              NaN
# 2017-01-04           NaN            NaN              NaN
# ...                  ...            ...              ...
# 2017-12-18    490.571429     482.933333       488.406593
# 2017-12-19    509.857143     499.366667       489.637363
# 2017-12-20    504.428571     494.700000       489.000000
# 2017-12-21    489.857143     490.433333       488.648352
# 2017-12-22    473.142857     485.366667       487.758242
#
# [12647 rows x 3 columns]

# %%
plt.figure(figsize=(10, 8))
penn['week_entries'].plot()
penn['month_entries'].plot()
penn['quarter_entries'].plot()
plt.legend();

# %%
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    
    # Iterate through each column name.
    for col in cols:
            
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18, rotation = 45);

# %%
plot_series(penn.resample('MS', ## YS is year start rather then y which is Year end
                        closed = 'left').sum(),
            ['Entries'],
            title = 'Average Entries',
            steps = 1)

# %%
['Entries']
# Out:
# ['Entries']

# %% [markdown]
# ### Jackson Heights
