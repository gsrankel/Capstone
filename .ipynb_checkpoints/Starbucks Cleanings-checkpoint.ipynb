# %% [markdown]
# # Subway Station Cleaning

# %% [markdown]
# ##

# %%
import numpy as np
import pandas as pd 
import requests
import time

# %%
starbucks = pd.read_csv('Data/Starbucks.csv')

# %%
station = pd.read_csv('Data/StationEntrances.csv')

# %% [markdown]
# Will read in starbucks and station data set with locations

# %%
starbucks = starbucks.loc[(starbucks['State/Province'] == 'NY') & (starbucks['City'].isin(['Flushing','New York','Astoria','Manhattan', 'Kew Gardens','Forest Hills','Jamaica']))]

# %% [markdown]
# Will filter out all locations that are around the MTA 'E' Subway line. We had to perfrom a guess and check on all towns that surrounded the various subway stops and the following cities came back with starbucks located in them

# %%
starbucks.head()
# Out:
#            Brand  Store Number              Store Name Ownership Type  \
# 20878  Starbucks  14840-129334          31-01 Broadway  Company Owned
# 20879  Starbucks  22638-223164  Astoria Blvd & 31st St  Company Owned
# 20880  Starbucks    9663-97893    35th Ave and 37th St  Company Owned
# 20881  Starbucks    7567-18640   31-44 Steinway Street  Company Owned
# 20882  Starbucks    7555-14690  31St St & Ditmars Blvd  Company Owned
#
#               Street Address     City State/Province Country   Postcode  \
# 20878         31-01 Broadway  Astoria             NY      US  111062648
# 20879     30-18 Astoria Blvd  Astoria             NY      US      11102
# 20880       3711 35th Avenue  Astoria             NY      US      11106
# 20881  31-44 Steinway Street  Astoria             NY      US  111033911
# 20882      22-04 31st Street  Astoria             NY      US  111052714
#
#        Phone Number                    Timezone  Longitude  Latitude
# 20878  718-777-1305  GMT-05:00 America/New_York     -73.93     40.76
# 20879    7182781518  GMT-05:00 America/New_York     -73.92     40.77
# 20880  718-706-0464  GMT-05:00 America/New_York     -73.92     40.76
# 20881  718-274-5700  GMT-05:00 America/New_York     -73.92     40.76
# 20882  718-626-6004  GMT-05:00 America/New_York     -73.91     40.78

# %%
starbucks.shape
# Out:
# (255, 13)

# %%
len(starbucks['Store Number'].unique())
# Out:
# 255

# %% [markdown]
# We checked len of each store number to confirm that there were no duplicates with store number as its the unique identifier column

# %%
starbucks['new_street'] = [i.replace(" ","") for i in starbucks['Street Address']]

# %%
starbucks['combined'] = starbucks['new_street']+starbucks['City']

# %%
starbucks['combined']
# Out:
# 20878              31-01BroadwayAstoria
# 20879           30-18AstoriaBlvdAstoria
# 20880             371135thAvenueAstoria
# 20881        31-44SteinwayStreetAstoria
# 20882            22-0431stStreetAstoria
#                       ...
# 21356      77-83West125thStreetNew York
# 21357              1740BroadwayNew York
# 21358                325W49thStNew York
# 21359    684AvenueoftheAmericasNew York
# 21360        30RockefellerPlazaNew York
# Name: combined, Length: 255, dtype: object

# %% [markdown]
# Feature engineer column to have one word for street address and city with no spaces

# %%
starbucks.head()
# Out:
#        Brand  Store Number              Store Name Ownership Type  \
# 0  Starbucks  14840-129334          31-01 Broadway  Company Owned
# 1  Starbucks  22638-223164  Astoria Blvd & 31st St  Company Owned
# 2  Starbucks    9663-97893    35th Ave and 37th St  Company Owned
# 3  Starbucks    7567-18640   31-44 Steinway Street  Company Owned
# 4  Starbucks    7539-12698      Main St & 41St Ave  Company Owned
#
#           Street Address      City State/Province Country   Postcode  \
# 0         31-01 Broadway   Astoria             NY      US  111062648
# 1     30-18 Astoria Blvd   Astoria             NY      US      11102
# 2       3711 35th Avenue   Astoria             NY      US      11106
# 3  31-44 Steinway Street   Astoria             NY      US  111033911
# 4      41-02 Main Street  Flushing             NY      US  113553133
#
#    Phone Number                    Timezone           new_street  \
# 0  718-777-1305  GMT-05:00 America/New_York        31-01Broadway
# 1    7182781518  GMT-05:00 America/New_York     30-18AstoriaBlvd
# 2  718-706-0464  GMT-05:00 America/New_York       371135thAvenue
# 3  718-274-5700  GMT-05:00 America/New_York  31-44SteinwayStreet
# 4  718-358-9355  GMT-05:00 America/New_York      41-02MainStreet
#
#                      combined   latitude  longitude
# 0        31-01BroadwayAstoria  40.762074 -73.925029
# 1     30-18AstoriaBlvdAstoria  40.769995 -73.918523
# 2       371135thAvenueAstoria  40.755939 -73.923485
# 3  31-44SteinwayStreetAstoria  40.760282 -73.918140
# 4     41-02MainStreetFlushing  40.757969 -73.829743

# %%
starbucks_coords = []
starbucks_store = []
missing_cords = []
for i in starbucks['combined']:
    try:
        response = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={i}ny&key=AIzaSyB11FgUKLMVHQLscEKwR6MhEHj81VFYl1Q')

        results = response.json()

        starbucks_coords.append(results['results'][0]['geometry']['location'])
        starbucks_store.append(i)
    except:
        missing_cords.append(i)
    time.sleep(2)

# %%
print(len(starbucks_coords))
print(len(starbucks_store))
# Out:
# 248
# 248

# %%
missing_cords
# Out:
# ['22-0431stStreetAstoria',
#  '1350520thAveFlushing',
#  '38ParkRow,#4New York',
#  '1000SEighthAvenue,#34New York',
#  '1117LexingtonAve.,#4New York',
#  '1291LexingtonAve.,#1291New York',
#  '1488ThirdAvenue#ANew York']

# %%
lat = []
long = []
for starbucks_coord in starbucks_coords:
    lat.append(starbucks_coord.get('lat'))
    long.append(starbucks_coord.get('lng'))

# %% [markdown]
# We will will a loop that will extract each latitude and longitude value from the coordinates pulled

# %%
lat_long = pd.DataFrame(data = {'combined': starbucks_store,
                    'latitude': lat,
                    'longitude': long})

# %%
lat_long.head()
# Out:
#                      combined   latitude  longitude
# 0        31-01BroadwayAstoria  40.762074 -73.925029
# 1     30-18AstoriaBlvdAstoria  40.769995 -73.918523
# 2       371135thAvenueAstoria  40.755939 -73.923485
# 3  31-44SteinwayStreetAstoria  40.760282 -73.918140
# 4     41-02MainStreetFlushing  40.757969 -73.829743

# %%
starbucks = pd.merge(left = starbucks,
        right = lat_long,
        how ='inner',
        on = 'combined')

# %% [markdown]
# Create a dataframe that we can merge back on with the latitude and longitudes of al the NY area stores

# %%
starbucks = pd.merge(left = starbucks,
        right = lat_long,
        how ='inner',
        on = 'combined')

# %%
starbucks.drop(columns= ['Longitude', 'Latitude'], inplace = True)
starbucks.head()
# Out:
#        Brand  Store Number              Store Name Ownership Type  \
# 0  Starbucks  14840-129334          31-01 Broadway  Company Owned
# 1  Starbucks  22638-223164  Astoria Blvd & 31st St  Company Owned
# 2  Starbucks    9663-97893    35th Ave and 37th St  Company Owned
# 3  Starbucks    7567-18640   31-44 Steinway Street  Company Owned
# 4  Starbucks    7539-12698      Main St & 41St Ave  Company Owned
#
#           Street Address      City State/Province Country   Postcode  \
# 0         31-01 Broadway   Astoria             NY      US  111062648
# 1     30-18 Astoria Blvd   Astoria             NY      US      11102
# 2       3711 35th Avenue   Astoria             NY      US      11106
# 3  31-44 Steinway Street   Astoria             NY      US  111033911
# 4      41-02 Main Street  Flushing             NY      US  113553133
#
#    Phone Number                    Timezone           new_street  \
# 0  718-777-1305  GMT-05:00 America/New_York        31-01Broadway
# 1    7182781518  GMT-05:00 America/New_York     30-18AstoriaBlvd
# 2  718-706-0464  GMT-05:00 America/New_York       371135thAvenue
# 3  718-274-5700  GMT-05:00 America/New_York  31-44SteinwayStreet
# 4  718-358-9355  GMT-05:00 America/New_York      41-02MainStreet
#
#                      combined   latitude  longitude
# 0        31-01BroadwayAstoria  40.762074 -73.925029
# 1     30-18AstoriaBlvdAstoria  40.769995 -73.918523
# 2       371135thAvenueAstoria  40.755939 -73.923485
# 3  31-44SteinwayStreetAstoria  40.760282 -73.918140
# 4     41-02MainStreetFlushing  40.757969 -73.829743

# %% [markdown]
# I create 3 fucntions to pull the distance of the 3 closest starbucks stores. These functions will take in the latitude and longitude coordinates of each subway station within our dataframe as well as the starbucks stores latitude and longitudes and use the pythagorean theorem to find the shortest distance between them. We will then list these distances and match them to the dataframe after

# %%
def closest_station(x1, y1, x2, y2): #x2, y2 series of lat and long for stations
    return pd.DataFrame((np.sqrt((x2 - x1)**2 + (y2-y1)**2)).sort_values()).iloc[0]

# %%
def closest_station2(x1, y1, x2, y2): #x2, y2 series of lat and long for stations
    return pd.DataFrame((np.sqrt((x2 - x1)**2 + (y2-y1)**2)).sort_values()).iloc[1]

# %%
def closest_station3(x1, y1, x2, y2): #x2, y2 series of lat and long for stations
    return pd.DataFrame((np.sqrt((x2 - x1)**2 + (y2-y1)**2)).sort_values()).iloc[2]

# %%
def closest_store(x1, y1, x2, y2): #x2, y2 series of lat and long for stations
    temp =  pd.DataFrame(data = [starbucks['Store Name'],(np.sqrt((x2 - x1)**2 + (y2-y1)**2))],index=[0,1])
    return temp.T.sort_values(by = 1).iloc[0][0]

# %%
def closest_store2(x1, y1, x2, y2): #x2, y2 series of lat and long for stations
    temp =  pd.DataFrame(data = [starbucks['Store Name'],(np.sqrt((x2 - x1)**2 + (y2-y1)**2))],index=[0,1])
    return temp.T.sort_values(by = 1).iloc[1][0]

# %%
def closest_store3(x1, y1, x2, y2): #x2, y2 series of lat and long for stations
    temp =  pd.DataFrame(data = [starbucks['Store Name'],(np.sqrt((x2 - x1)**2 + (y2-y1)**2))],index=[0,1])
    return temp.T.sort_values(by = 1).iloc[2][0]

# %%
closest_station(40.775149, -73.912074, starbucks['latitude'], starbucks['longitude'])
# Out:
# 0.008255377365080554

# %%
closest_store_1= []

# %%
closest_store(40.775149, -73.912074, starbucks['latitude'], starbucks['longitude'])
# Out:
# 'Astoria Blvd & 31st St'

# %% [markdown]
# Ensure that functions are working accordingly

# %%
first_closest = []
second_closest = []
third_closest = []
first_closest_store = []
second_closest_store = []
third_closest_store = []
for index in range(len(station)):
    row = station.iloc[index,:]
    lat = row['Latitude']
    long = row['Longitude']
    first_closest.append(closest_station(lat,long, starbucks['latitude'], starbucks['longitude']))
    second_closest.append(closest_station2(lat,long, starbucks['latitude'], starbucks['longitude']))
    third_closest.append(closest_station3(lat,long, starbucks['latitude'], starbucks['longitude']))
    first_closest_store.append(closest_store(lat,long, starbucks['latitude'], starbucks['longitude']))
    second_closest_store.append(closest_store2(lat,long, starbucks['latitude'], starbucks['longitude']))
    third_closest_store.append(closest_store3(lat,long, starbucks['latitude'], starbucks['longitude']))

# %%
print(len(first_closest))
print(len(second_closest))
print(len(third_closest))
print(len(first_closest_store))
print(len(second_closest_store))
print(len(third_closest_store))
# Out:
# 1866
# 1866
# 1866
# 1866
# 1866
# 1866

# %%
#function to add all the closest list to the dataframe
def add_to_df(df, distance, store_name, col1_name, col2_name):
    frame = pd.DataFrame([distance,store_name],index=[0,1])
    close = frame.T
    close.reset_index(drop=True, inplace=True)
    df[col1_name] = close[0]
    df[col2_name] = close[1]
    
    return df.head()

# %%
add_to_df(station,first_closest,first_closest_store,'first_closest','first_closest_store')
# Out:
#   Division     Line          Station_Name  Station_Latitude  \
# 0      BMT  Astoria          Ditmars Blvd         40.775036
# 1      BMT  Astoria          Ditmars Blvd         40.775036
# 2      BMT  Astoria          Ditmars Blvd         40.775036
# 3      BMT  Astoria          Ditmars Blvd         40.775036
# 4      BMT  Astoria  Astoria Blvd-Hoyt Av         40.770258
#
#    Station_Longitude Route_1 Route_2 Route_3 Route_4 Route_5  ...    ADA  \
# 0         -73.912034       N       Q     NaN     NaN     NaN  ...  False
# 1         -73.912034       N       Q     NaN     NaN     NaN  ...  False
# 2         -73.912034       N       Q     NaN     NaN     NaN  ...  False
# 3         -73.912034       N       Q     NaN     NaN     NaN  ...  False
# 4         -73.917843       N       Q     NaN     NaN     NaN  ...  False
#
#   ADA_Notes  Free_Crossover  North_South_Street  East_West_Street  Corner  \
# 0       NaN            True             31st St          23rd Ave      NW
# 1       NaN            True             31st St          23rd Ave      NE
# 2       NaN            True             31st St          23rd Ave      NE
# 3       NaN            True             31st St          23rd Ave      NW
# 4       NaN            True             31st St    Hoyt Ave South      SW
#
#     Latitude  Longitude first_closest     first_closest_store
# 0  40.775149 -73.912074    0.00825538  Astoria Blvd & 31st St
# 1  40.774810 -73.912151    0.00798653  Astoria Blvd & 31st St
# 2  40.775025 -73.911891     0.0083236  Astoria Blvd & 31st St
# 3  40.774938 -73.912337     0.0079182  Astoria Blvd & 31st St
# 4  40.770313 -73.917978    0.00063089  Astoria Blvd & 31st St
#
# [5 rows x 32 columns]

# %%
add_to_df(station,second_closest,second_closest_store,'second_closest','second_closest_store')
# Out:
#   Division     Line          Station_Name  Station_Latitude  \
# 0      BMT  Astoria          Ditmars Blvd         40.775036
# 1      BMT  Astoria          Ditmars Blvd         40.775036
# 2      BMT  Astoria          Ditmars Blvd         40.775036
# 3      BMT  Astoria          Ditmars Blvd         40.775036
# 4      BMT  Astoria  Astoria Blvd-Hoyt Av         40.770258
#
#    Station_Longitude Route_1 Route_2 Route_3 Route_4 Route_5  ...  \
# 0         -73.912034       N       Q     NaN     NaN     NaN  ...
# 1         -73.912034       N       Q     NaN     NaN     NaN  ...
# 2         -73.912034       N       Q     NaN     NaN     NaN  ...
# 3         -73.912034       N       Q     NaN     NaN     NaN  ...
# 4         -73.917843       N       Q     NaN     NaN     NaN  ...
#
#   Free_Crossover North_South_Street  East_West_Street  Corner   Latitude  \
# 0           True            31st St          23rd Ave      NW  40.775149
# 1           True            31st St          23rd Ave      NE  40.774810
# 2           True            31st St          23rd Ave      NE  40.775025
# 3           True            31st St          23rd Ave      NW  40.774938
# 4           True            31st St    Hoyt Ave South      SW  40.770313
#
#    Longitude first_closest     first_closest_store second_closest  \
# 0 -73.912074    0.00825538  Astoria Blvd & 31st St      0.0160565
# 1 -73.912151    0.00798653  Astoria Blvd & 31st St      0.0157136
# 2 -73.911891     0.0083236  Astoria Blvd & 31st St      0.0160123
# 3 -73.912337     0.0079182  Astoria Blvd & 31st St      0.0157626
# 4 -73.917978    0.00063089  Astoria Blvd & 31st St       0.010032
#
#     second_closest_store
# 0  31-44 Steinway Street
# 1  31-44 Steinway Street
# 2  31-44 Steinway Street
# 3  31-44 Steinway Street
# 4  31-44 Steinway Street
#
# [5 rows x 34 columns]

# %%
add_to_df(station,third_closest,third_closest_store,'third_closest','third_closest_store')
# Out:
#   Division     Line          Station_Name  Station_Latitude  \
# 0      BMT  Astoria          Ditmars Blvd         40.775036
# 1      BMT  Astoria          Ditmars Blvd         40.775036
# 2      BMT  Astoria          Ditmars Blvd         40.775036
# 3      BMT  Astoria          Ditmars Blvd         40.775036
# 4      BMT  Astoria  Astoria Blvd-Hoyt Av         40.770258
#
#    Station_Longitude Route_1 Route_2 Route_3 Route_4 Route_5  ...  \
# 0         -73.912034       N       Q     NaN     NaN     NaN  ...
# 1         -73.912034       N       Q     NaN     NaN     NaN  ...
# 2         -73.912034       N       Q     NaN     NaN     NaN  ...
# 3         -73.912034       N       Q     NaN     NaN     NaN  ...
# 4         -73.917843       N       Q     NaN     NaN     NaN  ...
#
#   East_West_Street Corner   Latitude  Longitude  first_closest  \
# 0         23rd Ave     NW  40.775149 -73.912074     0.00825538
# 1         23rd Ave     NE  40.774810 -73.912151     0.00798653
# 2         23rd Ave     NE  40.775025 -73.911891      0.0083236
# 3         23rd Ave     NW  40.774938 -73.912337      0.0079182
# 4   Hoyt Ave South     SW  40.770313 -73.917978     0.00063089
#
#       first_closest_store second_closest   second_closest_store third_closest  \
# 0  Astoria Blvd & 31st St      0.0160565  31-44 Steinway Street     0.0184057
# 1  Astoria Blvd & 31st St      0.0157136  31-44 Steinway Street     0.0181116
# 2  Astoria Blvd & 31st St      0.0160123  31-44 Steinway Street     0.0184477
# 3  Astoria Blvd & 31st St      0.0157626  31-44 Steinway Street     0.0180707
# 4  Astoria Blvd & 31st St       0.010032  31-44 Steinway Street     0.0108437
#
#   third_closest_store
# 0      31-01 Broadway
# 1      31-01 Broadway
# 2      31-01 Broadway
# 3      31-01 Broadway
# 4      31-01 Broadway
#
# [5 rows x 36 columns]

# %%
station.to_csv('data/stations.csv', index = False)
